# %% [markdown]
# - Predict the next number in the sequence (revisited)
#
# - The codes in this example is mostly the same as RNN_ex1, just change from `SimpleRNN()` to `LSTM()`.

# %% [markdown]
# # 1. Prepare the environment

# %%
# List all NVIDIA GPUs as available in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-956c85d2-46f5-1c66-c388-a40ea052b242)

# %%
import sys
print( f"Python {sys.version}\n" )

import numpy as np
print( f"NumPy {np.__version__}\n" )

import matplotlib.pyplot as plt
# %matplotlib inline

# https://keras.io/getting_started/
# The backend must be configured before importing Keras, and the backend cannot be changed after the package has been imported.
import os
os.environ["KERAS_BACKEND"] = "torch"  # "jax", "tensorflow"

import keras
print(f"Keras {keras.__version__}")
print(f"|- Keras backend = {keras.backend.backend()}")
print(f"|- Keras backend image data format = {keras.backend.image_data_format()}\n")

import torch
print( f"PyTorch {torch.__version__}" )

# Get all available accelerators such as CUDA, MPS, MTIA, or XPU
num_accelerators = torch.accelerator.device_count()

if (num_accelerators <= 0):
    print("|- No hardware accelerators found. Using CPU only.")
else:
    print(f"|- PyTorch detected {num_accelerators} hardware accelerator(s)")
    print(f"|- PyTorch detected '{torch.accelerator.current_accelerator().type.upper()}' as the current accelerator")

    # Check cuda availability
    if torch.cuda.is_available():
        num_gpus = torch.cuda.device_count()
        print(f"|- PyTorch detected {num_gpus} CUDA GPU(s):")
    for i in range(num_gpus):
        print(f"   |- CUDA GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
#
# NumPy 2.0.2
#
# Keras 3.10.0
# |- Keras backend = torch
# |- Keras backend image data format = channels_last
#
# PyTorch 2.8.0+cu126
# |- PyTorch detected 1 hardware accelerator(s)
# |- PyTorch detected 'CUDA' as the current accelerator
# |- PyTorch detected 1 CUDA GPU(s):
#    |- CUDA GPU 0: NVIDIA A100-SXM4-40GB

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed

# https://keras.io/examples/keras_recipes/reproducibility_recipes/
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
#keras.utils.set_random_seed(1234)

# %% [markdown]
# # 2. Create the simple 1-layer LSTM model

# %%
model = keras.models.Sequential()

# batch_size=None, time_steps=None, input_dim=1
# Output from this layer is (batch_size,units) which equals to (batch_size,20)
model.add( keras.layers.Input(shape=(None,1)) )
model.add( keras.layers.LSTM( units=20 ) )

# Use the default linear activation
model.add( keras.layers.Dense(1) )

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 20)             │         1,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,781 (6.96 KB)
#  Trainable params: 1,781 (6.96 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 3. Create train/val/test sets
#
# - Generate a 1D time series from `start_val` to `stop_val` with step 2:

# %%
start_val , stop_val = -4000 , 2000

# Create raw data
series = np.arange(start_val, stop_val+1, 2)
n_data = series.shape[0]

# Preview
print(f"{type(series)=} , {series.shape=} , {series}")
# Out:
# type(series)=<class 'numpy.ndarray'> , series.shape=(3001,) , [-4000 -3998 -3996 ...  1996  1998  2000]

# %% [markdown]
# - <u>Split the data from oldest to newest</u>: first 80% for training, next 10% for validation, last 10% for testing.
# - Compute the training statistics (mean and SD) <u>using only the training portion</u>.
# - Normalize the entire 1D sequence (z-score) using the training statistics.

# %%
# Split ratios
n_train = int(n_data * 0.8)         # 80% train
n_test = int(n_data * 0.1)          # 10% test
n_val = n_data - n_train - n_test   # 10% validation

# Compute training's mean and SD
train_mean = np.mean(series[:n_train])
train_std = np.std(series[:n_train])

# Normalize entire series using training stats
series_norm = (series - train_mean) / train_std
print(f"{type(series_norm)=} , {series_norm.shape=} , {series_norm}")
# Out:
# type(series_norm)=<class 'numpy.ndarray'> , series_norm.shape=(3001,) , [-1.73132927 -1.72988589 -1.72844252 ...  2.59591137  2.59735475
#   2.59879812]

# %% [markdown]
# - Split the normalized 1D sequence (`series_norm`) into input sequences `X_norm` (each containing `n_input_timesteps`=5 consecutive values) and targets `Y_norm` (the next value following each sequence). The unnormalized versions (`X` and `Y`) are kept only for reference.

# %%
# Sliding window parameters
n_input_timesteps = 5  # number of timesteps for input sequence

# Generate sliding windows
X, Y = [], []
X_norm, Y_norm = [], []
for i in range(len(series_norm) - n_input_timesteps):
    X.append(series[i:i+n_input_timesteps])
    Y.append(series[i+n_input_timesteps])

    X_norm.append(series_norm[i:i+n_input_timesteps])
    Y_norm.append(series_norm[i+n_input_timesteps])

X = np.array(X)
Y = np.array(Y)
X_norm = np.array(X_norm)
Y_norm = np.array(Y_norm)

# Preview
print(f"{type(X)=} , {X.shape=} , {X}")
print(f"{type(Y)=} , {Y.shape=} , {Y}\n")
print(f"{type(X_norm)=} , {X_norm.shape=} , {X_norm}")
print(f"{type(Y_norm)=} , {Y_norm.shape=} , {Y_norm}")
# Out:
# type(X)=<class 'numpy.ndarray'> , X.shape=(2996, 5) , [[-4000 -3998 -3996 -3994 -3992]
#  [-3998 -3996 -3994 -3992 -3990]
#  [-3996 -3994 -3992 -3990 -3988]
#  ...
#  [ 1986  1988  1990  1992  1994]
#  [ 1988  1990  1992  1994  1996]
#  [ 1990  1992  1994  1996  1998]]
# type(Y)=<class 'numpy.ndarray'> , Y.shape=(2996,) , [-3990 -3988 -3986 ...  1996  1998  2000]
#
# type(X_norm)=<class 'numpy.ndarray'> , X_norm.shape=(2996, 5) , [[-1.73132927 -1.72988589 -1.72844252 -1.72699914 -1.72555577]
#  [-1.72988589 -1.72844252 -1.72699914 -1.72555577 -1.72411239]
#  [-1.72844252 -1.72699914 -1.72555577 -1.72411239 -1.72266902]
#  ...
#  [ 2.58869449  2.59013787  2.59158125  2.59302462  2.594468  ]
#  [ 2.59013787  2.59158125  2.59302462  2.594468    2.59591137]
#  [ 2.59158125  2.59302462  2.594468    2.59591137  2.59735475]]
# type(Y_norm)=<class 'numpy.ndarray'> , Y_norm.shape=(2996,) , [-1.72411239 -1.72266902 -1.72122564 ...  2.59591137  2.59735475
#   2.59879812]

# %% [markdown]
# - Divide `X_norm` and `Y_norm` into training, validation, and test sets. The unnormalized versions are kept only for reference.
# - Reshape `X_norm` into `(batch_size, time_steps, input_dim)` as required by the SimpleRNN layer

# %%
# Split indices
train_end = n_train - n_input_timesteps
val_end = train_end + n_val

# Split into train/val/test
x_train = X[:train_end].reshape(-1, n_input_timesteps, 1)
y_train = Y[:train_end]
x_train_norm = X_norm[:train_end].reshape(-1, n_input_timesteps, 1)
y_train_norm = Y_norm[:train_end]

x_val = X[train_end:val_end].reshape(-1, n_input_timesteps, 1)
y_val = Y[train_end:val_end]
x_val_norm = X_norm[train_end:val_end].reshape(-1, n_input_timesteps, 1)
y_val_norm = Y_norm[train_end:val_end]

x_test = X[val_end:].reshape(-1, n_input_timesteps, 1)
y_test = Y[val_end:]
x_test_norm = X_norm[val_end:].reshape(-1, n_input_timesteps, 1)
y_test_norm = Y_norm[val_end:]

# Preview shapes
print(f"x_train shape: {x_train.shape}, y_train_norm shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val_norm shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test_norm shape: {y_test.shape}")
print(f"x_train_norm shape: {x_train_norm.shape}, y_train_norm shape: {y_train_norm.shape}")
print(f"x_val_norm shape: {x_val_norm.shape}, y_val_norm shape: {y_val_norm.shape}")
print(f"x_test_norm shape: {x_test_norm.shape}, y_test_norm shape: {y_test_norm.shape}")

# Preview first sample
print("\nFirst x_train sample:", x_train[0].ravel())
print("First y_train sample:", y_train[0])
print("First x_train_norm sample:", x_train_norm[0].ravel())
print("First y_train_norm sample:", y_train_norm[0])
# Out:
# x_train shape: (2395, 5, 1), y_train_norm shape: (2395,)
# x_val shape: (301, 5, 1), y_val_norm shape: (301,)
# x_test shape: (300, 5, 1), y_test_norm shape: (300,)
# x_train_norm shape: (2395, 5, 1), y_train_norm shape: (2395,)
# x_val_norm shape: (301, 5, 1), y_val_norm shape: (301,)
# x_test_norm shape: (300, 5, 1), y_test_norm shape: (300,)
#
# First x_train sample: [-4000 -3998 -3996 -3994 -3992]
# First y_train sample: -3990
# First x_train_norm sample: [-1.73132927 -1.72988589 -1.72844252 -1.72699914 -1.72555577]
# First y_train_norm sample: -1.7241123910300602

# %% [markdown]
# # 4. Compile and train the model

# %%
@keras.saving.register_keras_serializable(package="Custom", name="mae_denorm")
def mae_denorm(y_true, y_pred):
    # y_true and y_pred are normalized
    y_true_denorm = (y_true * train_std) + train_mean
    y_pred_denorm = (y_pred * train_std) + train_mean
    return torch.mean(torch.abs(y_true_denorm - y_pred_denorm))

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)

# For regression, the loss can be used as the evaluation metric as well
model.compile( loss="mse", optimizer=adam, metrics=['mae',mae_denorm] )

# %%
checkpoint_filepath = "LSTM_ex1_bestmodel_epoch{epoch:03d}.keras"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint( filepath=checkpoint_filepath,
                                                              save_weights_only=False,
                                                              monitor='val_loss',
                                                              mode='min',
                                                              save_best_only=True)

# %%
hist = model.fit ( x_train_norm, y_train_norm,
                   validation_data=(x_val_norm,y_val_norm),
                   batch_size=64, epochs=300,
                   callbacks=[model_checkpoint_callback] )
# Out:
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 1.1862 - mae: 0.9428 - mae_denorm: 1216.9062 - val_loss: 3.0441 - val_mae: 1.7402 - val_mae_denorm: 2426.5784
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5589 - mae: 0.6262 - mae_denorm: 1220.4391 - val_loss: 1.2245 - val_mae: 1.1010 - val_mae_denorm: 1539.1741
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1277 - mae: 0.2616 - mae_denorm: 1381.0247 - val_loss: 0.2902 - val_mae: 0.5289 - val_mae_denorm: 745.4369
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0223 - mae: 0.1287 - mae_denorm: 1558.9602 - val_loss: 0.2309 - val_mae: 0.4705 - val_mae_denorm: 664.0204
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0176 - mae: 0.1137 - mae_denorm: 1567.2124 - val_loss: 0.2014 - val_mae: 0.4391 - val_mae_denorm: 619.8586
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0133 - mae: 0.0983 - mae_denorm: 1559.5804 - val_loss: 0.1629 - val_mae: 0.3941 - val_mae_denorm: 556.8918
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0102 - mae: 0.0867 - mae_denorm: 1556.3197 - val_loss: 0.1290 - val_mae: 0.3499 - val_mae_denorm: 494.9496
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0075 - mae: 0.0743 - mae_denorm: 1565.3976 - val_loss: 0.1105 - val_mae: 0.3237 - val_mae_denorm: 457.9626
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0053 - mae: 0.0614 - mae_denorm: 1553.4854 - val_loss: 0.0801 - val_mae: 0.2741 - val_mae_denorm: 388.6292
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0040 - mae: 0.0527 - mae_denorm: 1577.3129 - val_loss: 0.0629 - val_mae: 0.2422 - val_mae_denorm: 343.8483
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025 - mae: 0.0407 - mae_denorm: 1570.3900 - val_loss: 0.0487 - val_mae: 0.2122 - val_mae_denorm: 301.7751
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - mae: 0.0338 - mae_denorm: 1573.3541 - val_loss: 0.0398 - val_mae: 0.1911 - val_mae_denorm: 272.0803
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0264 - mae_denorm: 1575.8683 - val_loss: 0.0314 - val_mae: 0.1689 - val_mae_denorm: 240.8893
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4629e-04 - mae: 0.0211 - mae_denorm: 1568.4647 - val_loss: 0.0242 - val_mae: 0.1468 - val_mae_denorm: 209.9934
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9816e-04 - mae: 0.0162 - mae_denorm: 1575.7599 - val_loss: 0.0207 - val_mae: 0.1351 - val_mae_denorm: 193.5504
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6031e-04 - mae: 0.0139 - mae_denorm: 1593.3629 - val_loss: 0.0185 - val_mae: 0.1273 - val_mae_denorm: 182.5868
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8288e-04 - mae: 0.0118 - mae_denorm: 1585.0664 - val_loss: 0.0160 - val_mae: 0.1180 - val_mae_denorm: 169.5998
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0994e-04 - mae: 0.0104 - mae_denorm: 1592.5306 - val_loss: 0.0139 - val_mae: 0.1090 - val_mae_denorm: 157.2218
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8201e-04 - mae: 0.0103 - mae_denorm: 1574.5748 - val_loss: 0.0133 - val_mae: 0.1065 - val_mae_denorm: 153.7748
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6608e-04 - mae: 0.0100 - mae_denorm: 1571.2562 - val_loss: 0.0127 - val_mae: 0.1037 - val_mae_denorm: 149.8766
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5355e-04 - mae: 0.0100 - mae_denorm: 1591.0929 - val_loss: 0.0119 - val_mae: 0.1001 - val_mae_denorm: 145.0429
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4258e-04 - mae: 0.0098 - mae_denorm: 1569.8638 - val_loss: 0.0121 - val_mae: 0.1014 - val_mae_denorm: 146.7543
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4094e-04 - mae: 0.0098 - mae_denorm: 1595.2051 - val_loss: 0.0117 - val_mae: 0.0993 - val_mae_denorm: 143.8174
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2595e-04 - mae: 0.0094 - mae_denorm: 1561.4783 - val_loss: 0.0112 - val_mae: 0.0968 - val_mae_denorm: 140.4838
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3464e-04 - mae: 0.0097 - mae_denorm: 1582.5427 - val_loss: 0.0108 - val_mae: 0.0951 - val_mae_denorm: 138.2687
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3189e-04 - mae: 0.0097 - mae_denorm: 1560.0820 - val_loss: 0.0111 - val_mae: 0.0964 - val_mae_denorm: 139.9802
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2156e-04 - mae: 0.0093 - mae_denorm: 1566.2295 - val_loss: 0.0107 - val_mae: 0.0944 - val_mae_denorm: 137.2933
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2498e-04 - mae: 0.0094 - mae_denorm: 1571.9252 - val_loss: 0.0108 - val_mae: 0.0949 - val_mae_denorm: 137.8462
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1673e-04 - mae: 0.0092 - mae_denorm: 1578.8425 - val_loss: 0.0104 - val_mae: 0.0930 - val_mae_denorm: 135.3618
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2240e-04 - mae: 0.0093 - mae_denorm: 1586.0509 - val_loss: 0.0110 - val_mae: 0.0963 - val_mae_denorm: 139.6380
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1557e-04 - mae: 0.0091 - mae_denorm: 1596.5052 - val_loss: 0.0101 - val_mae: 0.0918 - val_mae_denorm: 133.7005
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0879e-04 - mae: 0.0088 - mae_denorm: 1551.2649 - val_loss: 0.0107 - val_mae: 0.0948 - val_mae_denorm: 137.7023
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1147e-04 - mae: 0.0088 - mae_denorm: 1589.6882 - val_loss: 0.0100 - val_mae: 0.0912 - val_mae_denorm: 132.8782
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0443e-04 - mae: 0.0087 - mae_denorm: 1567.2625 - val_loss: 0.0107 - val_mae: 0.0948 - val_mae_denorm: 137.5764
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0281e-04 - mae: 0.0085 - mae_denorm: 1582.6320 - val_loss: 0.0100 - val_mae: 0.0914 - val_mae_denorm: 133.1345
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0316e-04 - mae: 0.0085 - mae_denorm: 1589.3601 - val_loss: 0.0101 - val_mae: 0.0920 - val_mae_denorm: 133.8199
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0245e-04 - mae: 0.0086 - mae_denorm: 1576.3367 - val_loss: 0.0102 - val_mae: 0.0926 - val_mae_denorm: 134.6419
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.4672e-05 - mae: 0.0082 - mae_denorm: 1543.5321 - val_loss: 0.0103 - val_mae: 0.0934 - val_mae_denorm: 135.5776
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.8289e-05 - mae: 0.0080 - mae_denorm: 1564.8689 - val_loss: 0.0096 - val_mae: 0.0894 - val_mae_denorm: 130.3626
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.2359e-05 - mae: 0.0081 - mae_denorm: 1581.5597 - val_loss: 0.0093 - val_mae: 0.0878 - val_mae_denorm: 128.2529
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.2704e-05 - mae: 0.0081 - mae_denorm: 1582.6388 - val_loss: 0.0096 - val_mae: 0.0895 - val_mae_denorm: 130.4058
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4923e-05 - mae: 0.0078 - mae_denorm: 1555.3716 - val_loss: 0.0094 - val_mae: 0.0885 - val_mae_denorm: 129.0477
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1454e-05 - mae: 0.0076 - mae_denorm: 1571.8203 - val_loss: 0.0089 - val_mae: 0.0856 - val_mae_denorm: 125.2324
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3906e-05 - mae: 0.0077 - mae_denorm: 1564.5555 - val_loss: 0.0084 - val_mae: 0.0828 - val_mae_denorm: 121.6037
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1144e-05 - mae: 0.0076 - mae_denorm: 1559.5363 - val_loss: 0.0088 - val_mae: 0.0853 - val_mae_denorm: 124.7062
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2073e-05 - mae: 0.0077 - mae_denorm: 1563.8717 - val_loss: 0.0089 - val_mae: 0.0863 - val_mae_denorm: 125.9395
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.9171e-05 - mae: 0.0075 - mae_denorm: 1565.9860 - val_loss: 0.0088 - val_mae: 0.0855 - val_mae_denorm: 124.8578
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6461e-05 - mae: 0.0073 - mae_denorm: 1572.0482 - val_loss: 0.0077 - val_mae: 0.0794 - val_mae_denorm: 117.1070
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4692e-05 - mae: 0.0073 - mae_denorm: 1564.8179 - val_loss: 0.0078 - val_mae: 0.0797 - val_mae_denorm: 117.3877
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0434e-05 - mae: 0.0071 - mae_denorm: 1577.9979 - val_loss: 0.0089 - val_mae: 0.0867 - val_mae_denorm: 126.2597
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1024e-05 - mae: 0.0071 - mae_denorm: 1568.5610 - val_loss: 0.0082 - val_mae: 0.0824 - val_mae_denorm: 120.7319
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.6108e-05 - mae: 0.0069 - mae_denorm: 1528.8446 - val_loss: 0.0083 - val_mae: 0.0832 - val_mae_denorm: 121.6402
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4728e-05 - mae: 0.0069 - mae_denorm: 1576.0314 - val_loss: 0.0082 - val_mae: 0.0829 - val_mae_denorm: 121.1957
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.2386e-05 - mae: 0.0067 - mae_denorm: 1555.7911 - val_loss: 0.0080 - val_mae: 0.0816 - val_mae_denorm: 119.5567
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.2617e-05 - mae: 0.0066 - mae_denorm: 1587.4596 - val_loss: 0.0068 - val_mae: 0.0741 - val_mae_denorm: 110.1335
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4349e-05 - mae: 0.0067 - mae_denorm: 1588.3511 - val_loss: 0.0074 - val_mae: 0.0779 - val_mae_denorm: 114.7071
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8165e-05 - mae: 0.0064 - mae_denorm: 1564.6968 - val_loss: 0.0074 - val_mae: 0.0783 - val_mae_denorm: 115.2137
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8953e-05 - mae: 0.0064 - mae_denorm: 1580.9744 - val_loss: 0.0075 - val_mae: 0.0788 - val_mae_denorm: 115.6537
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4855e-05 - mae: 0.0063 - mae_denorm: 1554.2615 - val_loss: 0.0073 - val_mae: 0.0777 - val_mae_denorm: 114.2282
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3911e-05 - mae: 0.0061 - mae_denorm: 1566.3699 - val_loss: 0.0072 - val_mae: 0.0773 - val_mae_denorm: 113.6526
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4829e-05 - mae: 0.0062 - mae_denorm: 1571.1755 - val_loss: 0.0072 - val_mae: 0.0771 - val_mae_denorm: 113.4171
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2455e-05 - mae: 0.0061 - mae_denorm: 1582.7448 - val_loss: 0.0077 - val_mae: 0.0806 - val_mae_denorm: 117.7005
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6166e-05 - mae: 0.0063 - mae_denorm: 1571.1129 - val_loss: 0.0063 - val_mae: 0.0714 - val_mae_denorm: 106.2610
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2922e-05 - mae: 0.0061 - mae_denorm: 1565.6938 - val_loss: 0.0066 - val_mae: 0.0740 - val_mae_denorm: 109.3371
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7790e-05 - mae: 0.0058 - mae_denorm: 1563.6553 - val_loss: 0.0069 - val_mae: 0.0759 - val_mae_denorm: 111.5917
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8663e-05 - mae: 0.0059 - mae_denorm: 1557.8086 - val_loss: 0.0061 - val_mae: 0.0708 - val_mae_denorm: 105.3247
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5190e-05 - mae: 0.0057 - mae_denorm: 1567.4111 - val_loss: 0.0065 - val_mae: 0.0733 - val_mae_denorm: 108.2286
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4842e-05 - mae: 0.0056 - mae_denorm: 1551.3934 - val_loss: 0.0063 - val_mae: 0.0721 - val_mae_denorm: 106.7657
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4715e-05 - mae: 0.0057 - mae_denorm: 1576.1180 - val_loss: 0.0070 - val_mae: 0.0772 - val_mae_denorm: 113.0627
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4041e-05 - mae: 0.0055 - mae_denorm: 1580.0028 - val_loss: 0.0063 - val_mae: 0.0725 - val_mae_denorm: 107.0343
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2915e-05 - mae: 0.0055 - mae_denorm: 1576.0815 - val_loss: 0.0059 - val_mae: 0.0699 - val_mae_denorm: 103.8597
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9661e-05 - mae: 0.0053 - mae_denorm: 1554.5354 - val_loss: 0.0056 - val_mae: 0.0675 - val_mae_denorm: 100.8838
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9435e-05 - mae: 0.0053 - mae_denorm: 1574.0487 - val_loss: 0.0055 - val_mae: 0.0672 - val_mae_denorm: 100.4630
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8278e-05 - mae: 0.0052 - mae_denorm: 1563.8116 - val_loss: 0.0052 - val_mae: 0.0648 - val_mae_denorm: 97.5314
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7905e-05 - mae: 0.0051 - mae_denorm: 1576.9656 - val_loss: 0.0055 - val_mae: 0.0673 - val_mae_denorm: 100.4419
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6628e-05 - mae: 0.0051 - mae_denorm: 1587.3240 - val_loss: 0.0055 - val_mae: 0.0671 - val_mae_denorm: 100.1690
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6241e-05 - mae: 0.0050 - mae_denorm: 1543.3821 - val_loss: 0.0058 - val_mae: 0.0694 - val_mae_denorm: 102.8760
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3102e-05 - mae: 0.0048 - mae_denorm: 1566.0836 - val_loss: 0.0054 - val_mae: 0.0672 - val_mae_denorm: 100.0742
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2939e-05 - mae: 0.0048 - mae_denorm: 1548.8760 - val_loss: 0.0053 - val_mae: 0.0663 - val_mae_denorm: 98.9297
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4381e-05 - mae: 0.0049 - mae_denorm: 1567.6530 - val_loss: 0.0053 - val_mae: 0.0661 - val_mae_denorm: 98.5780
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3278e-05 - mae: 0.0048 - mae_denorm: 1568.6718 - val_loss: 0.0049 - val_mae: 0.0630 - val_mae_denorm: 94.9179
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9557e-05 - mae: 0.0045 - mae_denorm: 1542.6958 - val_loss: 0.0044 - val_mae: 0.0590 - val_mae_denorm: 90.2386
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1638e-05 - mae: 0.0047 - mae_denorm: 1572.7422 - val_loss: 0.0051 - val_mae: 0.0655 - val_mae_denorm: 97.6525
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4069e-05 - mae: 0.0048 - mae_denorm: 1568.7194 - val_loss: 0.0046 - val_mae: 0.0609 - val_mae_denorm: 92.2622
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9284e-05 - mae: 0.0045 - mae_denorm: 1563.0303 - val_loss: 0.0046 - val_mae: 0.0615 - val_mae_denorm: 92.8580
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8285e-05 - mae: 0.0044 - mae_denorm: 1553.8638 - val_loss: 0.0047 - val_mae: 0.0625 - val_mae_denorm: 94.0012
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7191e-05 - mae: 0.0044 - mae_denorm: 1555.1218 - val_loss: 0.0042 - val_mae: 0.0581 - val_mae_denorm: 88.8041
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9049e-05 - mae: 0.0045 - mae_denorm: 1578.0646 - val_loss: 0.0043 - val_mae: 0.0594 - val_mae_denorm: 90.1997
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8476e-05 - mae: 0.0044 - mae_denorm: 1563.8993 - val_loss: 0.0047 - val_mae: 0.0625 - val_mae_denorm: 93.6964
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6237e-05 - mae: 0.0042 - mae_denorm: 1583.1523 - val_loss: 0.0041 - val_mae: 0.0580 - val_mae_denorm: 88.4792
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4650e-05 - mae: 0.0041 - mae_denorm: 1555.0739 - val_loss: 0.0039 - val_mae: 0.0564 - val_mae_denorm: 86.6072
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3977e-05 - mae: 0.0041 - mae_denorm: 1562.3551 - val_loss: 0.0039 - val_mae: 0.0563 - val_mae_denorm: 86.4186
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5318e-05 - mae: 0.0042 - mae_denorm: 1583.7871 - val_loss: 0.0041 - val_mae: 0.0580 - val_mae_denorm: 88.2448
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2878e-05 - mae: 0.0039 - mae_denorm: 1589.8734 - val_loss: 0.0037 - val_mae: 0.0549 - val_mae_denorm: 84.7111
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5420e-05 - mae: 0.0041 - mae_denorm: 1598.8323 - val_loss: 0.0040 - val_mae: 0.0576 - val_mae_denorm: 87.7350
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1306e-05 - mae: 0.0038 - mae_denorm: 1565.1377 - val_loss: 0.0039 - val_mae: 0.0569 - val_mae_denorm: 86.8294
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1087e-05 - mae: 0.0038 - mae_denorm: 1570.3225 - val_loss: 0.0040 - val_mae: 0.0576 - val_mae_denorm: 87.5355
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0980e-05 - mae: 0.0037 - mae_denorm: 1578.8191 - val_loss: 0.0035 - val_mae: 0.0533 - val_mae_denorm: 82.6994
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1356e-05 - mae: 0.0037 - mae_denorm: 1590.7251 - val_loss: 0.0038 - val_mae: 0.0562 - val_mae_denorm: 85.8380
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1012e-05 - mae: 0.0037 - mae_denorm: 1592.1163 - val_loss: 0.0035 - val_mae: 0.0529 - val_mae_denorm: 82.1136
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1152e-05 - mae: 0.0038 - mae_denorm: 1596.2262 - val_loss: 0.0027 - val_mae: 0.0449 - val_mae_denorm: 73.6741
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0434e-05 - mae: 0.0037 - mae_denorm: 1604.9253 - val_loss: 0.0035 - val_mae: 0.0538 - val_mae_denorm: 82.9438
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7091e-05 - mae: 0.0034 - mae_denorm: 1568.8560 - val_loss: 0.0031 - val_mae: 0.0495 - val_mae_denorm: 78.1582
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8053e-05 - mae: 0.0034 - mae_denorm: 1565.9825 - val_loss: 0.0031 - val_mae: 0.0504 - val_mae_denorm: 79.0900
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6948e-05 - mae: 0.0034 - mae_denorm: 1573.5261 - val_loss: 0.0032 - val_mae: 0.0508 - val_mae_denorm: 79.4212
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6415e-05 - mae: 0.0033 - mae_denorm: 1552.7926 - val_loss: 0.0030 - val_mae: 0.0493 - val_mae_denorm: 77.7404
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5606e-05 - mae: 0.0033 - mae_denorm: 1561.4940 - val_loss: 0.0028 - val_mae: 0.0468 - val_mae_denorm: 75.1054
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6144e-05 - mae: 0.0032 - mae_denorm: 1557.3234 - val_loss: 0.0030 - val_mae: 0.0496 - val_mae_denorm: 77.9401
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5287e-05 - mae: 0.0032 - mae_denorm: 1582.8507 - val_loss: 0.0029 - val_mae: 0.0482 - val_mae_denorm: 76.3738
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4287e-05 - mae: 0.0031 - mae_denorm: 1565.6561 - val_loss: 0.0029 - val_mae: 0.0484 - val_mae_denorm: 76.5516
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3766e-05 - mae: 0.0030 - mae_denorm: 1586.5653 - val_loss: 0.0029 - val_mae: 0.0486 - val_mae_denorm: 76.6266
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2916e-05 - mae: 0.0030 - mae_denorm: 1553.6251 - val_loss: 0.0026 - val_mae: 0.0458 - val_mae_denorm: 73.6740
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4534e-05 - mae: 0.0031 - mae_denorm: 1565.5162 - val_loss: 0.0028 - val_mae: 0.0475 - val_mae_denorm: 75.3611
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3855e-05 - mae: 0.0030 - mae_denorm: 1571.8418 - val_loss: 0.0026 - val_mae: 0.0459 - val_mae_denorm: 73.6211
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3372e-05 - mae: 0.0030 - mae_denorm: 1588.0482 - val_loss: 0.0024 - val_mae: 0.0430 - val_mae_denorm: 70.6817
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1978e-05 - mae: 0.0028 - mae_denorm: 1561.5189 - val_loss: 0.0027 - val_mae: 0.0466 - val_mae_denorm: 74.2922
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3541e-05 - mae: 0.0029 - mae_denorm: 1568.4762 - val_loss: 0.0023 - val_mae: 0.0422 - val_mae_denorm: 69.7257
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2358e-05 - mae: 0.0028 - mae_denorm: 1556.6968 - val_loss: 0.0024 - val_mae: 0.0439 - val_mae_denorm: 71.2914
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0846e-05 - mae: 0.0027 - mae_denorm: 1592.7953 - val_loss: 0.0021 - val_mae: 0.0402 - val_mae_denorm: 67.6685
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0411e-05 - mae: 0.0026 - mae_denorm: 1548.5032 - val_loss: 0.0025 - val_mae: 0.0449 - val_mae_denorm: 72.1734
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.4498e-06 - mae: 0.0025 - mae_denorm: 1559.5819 - val_loss: 0.0024 - val_mae: 0.0439 - val_mae_denorm: 71.1884
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.7033e-06 - mae: 0.0025 - mae_denorm: 1568.1603 - val_loss: 0.0023 - val_mae: 0.0427 - val_mae_denorm: 69.8212
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9833e-06 - mae: 0.0024 - mae_denorm: 1579.8182 - val_loss: 0.0020 - val_mae: 0.0397 - val_mae_denorm: 66.9617
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0116e-05 - mae: 0.0025 - mae_denorm: 1552.6334 - val_loss: 0.0018 - val_mae: 0.0376 - val_mae_denorm: 64.9074
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.0716e-06 - mae: 0.0024 - mae_denorm: 1569.9156 - val_loss: 0.0019 - val_mae: 0.0382 - val_mae_denorm: 65.3334
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8921e-06 - mae: 0.0023 - mae_denorm: 1556.1134 - val_loss: 0.0019 - val_mae: 0.0392 - val_mae_denorm: 66.2530
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1412e-06 - mae: 0.0023 - mae_denorm: 1598.7633 - val_loss: 0.0019 - val_mae: 0.0393 - val_mae_denorm: 66.2535
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1216e-06 - mae: 0.0021 - mae_denorm: 1562.6948 - val_loss: 0.0019 - val_mae: 0.0386 - val_mae_denorm: 65.5722
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1990e-06 - mae: 0.0022 - mae_denorm: 1586.0648 - val_loss: 0.0018 - val_mae: 0.0378 - val_mae_denorm: 64.7285
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3400e-06 - mae: 0.0021 - mae_denorm: 1587.8033 - val_loss: 0.0018 - val_mae: 0.0379 - val_mae_denorm: 64.7805
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0194e-06 - mae: 0.0021 - mae_denorm: 1568.2676 - val_loss: 0.0015 - val_mae: 0.0329 - val_mae_denorm: 60.2976
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4914e-06 - mae: 0.0020 - mae_denorm: 1556.7937 - val_loss: 0.0017 - val_mae: 0.0369 - val_mae_denorm: 63.7671
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.9510e-06 - mae: 0.0020 - mae_denorm: 1581.8225 - val_loss: 0.0016 - val_mae: 0.0348 - val_mae_denorm: 61.7556
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.0234e-06 - mae: 0.0020 - mae_denorm: 1583.7047 - val_loss: 0.0017 - val_mae: 0.0368 - val_mae_denorm: 63.4717
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3684e-06 - mae: 0.0018 - mae_denorm: 1566.9117 - val_loss: 0.0016 - val_mae: 0.0358 - val_mae_denorm: 62.5413
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9854e-06 - mae: 0.0018 - mae_denorm: 1547.6653 - val_loss: 0.0016 - val_mae: 0.0349 - val_mae_denorm: 61.6244
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4829e-06 - mae: 0.0019 - mae_denorm: 1568.4122 - val_loss: 0.0016 - val_mae: 0.0353 - val_mae_denorm: 61.9748
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2213e-06 - mae: 0.0017 - mae_denorm: 1529.8169 - val_loss: 0.0015 - val_mae: 0.0346 - val_mae_denorm: 61.3121
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4349e-06 - mae: 0.0018 - mae_denorm: 1579.4299 - val_loss: 0.0013 - val_mae: 0.0308 - val_mae_denorm: 57.9642
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7536e-06 - mae: 0.0017 - mae_denorm: 1585.1401 - val_loss: 0.0015 - val_mae: 0.0349 - val_mae_denorm: 61.4203
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1038e-06 - mae: 0.0016 - mae_denorm: 1557.5682 - val_loss: 0.0014 - val_mae: 0.0329 - val_mae_denorm: 59.6189
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7643e-06 - mae: 0.0015 - mae_denorm: 1559.2458 - val_loss: 0.0012 - val_mae: 0.0305 - val_mae_denorm: 57.5198
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3335e-06 - mae: 0.0014 - mae_denorm: 1557.8163 - val_loss: 0.0011 - val_mae: 0.0286 - val_mae_denorm: 55.9415
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1447e-06 - mae: 0.0015 - mae_denorm: 1562.9117 - val_loss: 0.0011 - val_mae: 0.0287 - val_mae_denorm: 55.9572
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6759e-06 - mae: 0.0015 - mae_denorm: 1579.0504 - val_loss: 0.0012 - val_mae: 0.0299 - val_mae_denorm: 56.8318
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2524e-06 - mae: 0.0014 - mae_denorm: 1585.9709 - val_loss: 0.0012 - val_mae: 0.0300 - val_mae_denorm: 56.9170
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0923e-06 - mae: 0.0013 - mae_denorm: 1569.6045 - val_loss: 0.0011 - val_mae: 0.0294 - val_mae_denorm: 56.3924
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5529e-06 - mae: 0.0014 - mae_denorm: 1543.4150 - val_loss: 0.0011 - val_mae: 0.0296 - val_mae_denorm: 56.4375
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1755e-06 - mae: 0.0013 - mae_denorm: 1556.8457 - val_loss: 0.0010 - val_mae: 0.0277 - val_mae_denorm: 54.8816
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8886e-06 - mae: 0.0015 - mae_denorm: 1580.2299 - val_loss: 0.0011 - val_mae: 0.0288 - val_mae_denorm: 55.7445
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4029e-06 - mae: 0.0011 - mae_denorm: 1560.3103 - val_loss: 0.0011 - val_mae: 0.0288 - val_mae_denorm: 55.6662
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4870e-06 - mae: 0.0012 - mae_denorm: 1581.7816 - val_loss: 0.0010 - val_mae: 0.0279 - val_mae_denorm: 54.9495
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2873e-06 - mae: 0.0011 - mae_denorm: 1558.9612 - val_loss: 0.0010 - val_mae: 0.0276 - val_mae_denorm: 54.6356
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1456e-06 - mae: 0.0011 - mae_denorm: 1562.7239 - val_loss: 0.0010 - val_mae: 0.0277 - val_mae_denorm: 54.6314
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3568e-06 - mae: 0.0011 - mae_denorm: 1582.6346 - val_loss: 0.0011 - val_mae: 0.0289 - val_mae_denorm: 55.5567
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2620e-06 - mae: 0.0011 - mae_denorm: 1570.7645 - val_loss: 9.9113e-04 - val_mae: 0.0275 - val_mae_denorm: 54.4135
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0867e-06 - mae: 0.0011 - mae_denorm: 1583.2836 - val_loss: 9.5497e-04 - val_mae: 0.0270 - val_mae_denorm: 53.9203
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5416e-06 - mae: 9.0231e-04 - mae_denorm: 1563.5532 - val_loss: 9.2370e-04 - val_mae: 0.0264 - val_mae_denorm: 53.4870
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4395e-06 - mae: 8.8560e-04 - mae_denorm: 1588.7134 - val_loss: 9.9507e-04 - val_mae: 0.0278 - val_mae_denorm: 54.4892
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7946e-06 - mae: 9.3285e-04 - mae_denorm: 1585.5616 - val_loss: 9.1413e-04 - val_mae: 0.0264 - val_mae_denorm: 53.3663
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3262e-06 - mae: 8.1001e-04 - mae_denorm: 1559.4884 - val_loss: 7.3748e-04 - val_mae: 0.0229 - val_mae_denorm: 50.8424
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9770e-06 - mae: 9.7889e-04 - mae_denorm: 1572.5364 - val_loss: 8.3329e-04 - val_mae: 0.0250 - val_mae_denorm: 52.2307
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2446e-06 - mae: 0.0011 - mae_denorm: 1549.2151 - val_loss: 7.5679e-04 - val_mae: 0.0235 - val_mae_denorm: 51.1411
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1222e-06 - mae: 7.8093e-04 - mae_denorm: 1575.2266 - val_loss: 7.8822e-04 - val_mae: 0.0242 - val_mae_denorm: 51.5973
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4559e-06 - mae: 8.4664e-04 - mae_denorm: 1589.1062 - val_loss: 8.0735e-04 - val_mae: 0.0246 - val_mae_denorm: 51.8780
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6351e-06 - mae: 9.0079e-04 - mae_denorm: 1595.0574 - val_loss: 7.9505e-04 - val_mae: 0.0245 - val_mae_denorm: 51.7073
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4915e-06 - mae: 8.4347e-04 - mae_denorm: 1560.8185 - val_loss: 7.5810e-04 - val_mae: 0.0238 - val_mae_denorm: 51.1771
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.5041e-07 - mae: 6.8609e-04 - mae_denorm: 1573.0437 - val_loss: 8.1917e-04 - val_mae: 0.0251 - val_mae_denorm: 52.0631
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0980e-06 - mae: 7.2073e-04 - mae_denorm: 1565.3083 - val_loss: 7.6921e-04 - val_mae: 0.0242 - val_mae_denorm: 51.3536
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.3808e-07 - mae: 6.6235e-04 - mae_denorm: 1577.3784 - val_loss: 6.3051e-04 - val_mae: 0.0212 - val_mae_denorm: 49.3153
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.6388e-07 - mae: 6.8011e-04 - mae_denorm: 1563.3212 - val_loss: 6.7461e-04 - val_mae: 0.0222 - val_mae_denorm: 49.9776
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.4914e-07 - mae: 6.7568e-04 - mae_denorm: 1582.2386 - val_loss: 7.1860e-04 - val_mae: 0.0232 - val_mae_denorm: 50.6243
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1891e-07 - mae: 5.6432e-04 - mae_denorm: 1573.1934 - val_loss: 6.8170e-04 - val_mae: 0.0225 - val_mae_denorm: 50.0895
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.6348e-07 - mae: 5.5761e-04 - mae_denorm: 1557.5100 - val_loss: 6.9353e-04 - val_mae: 0.0228 - val_mae_denorm: 50.2670
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.9577e-07 - mae: 6.2066e-04 - mae_denorm: 1553.4164 - val_loss: 6.0561e-04 - val_mae: 0.0208 - val_mae_denorm: 48.9642
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1839e-06 - mae: 7.7449e-04 - mae_denorm: 1562.3983 - val_loss: 5.9634e-04 - val_mae: 0.0206 - val_mae_denorm: 48.8266
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.2196e-07 - mae: 5.4308e-04 - mae_denorm: 1559.3353 - val_loss: 6.5986e-04 - val_mae: 0.0222 - val_mae_denorm: 49.7802
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.7583e-07 - mae: 6.1144e-04 - mae_denorm: 1586.2006 - val_loss: 6.3156e-04 - val_mae: 0.0216 - val_mae_denorm: 49.3657
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0572e-07 - mae: 5.9483e-04 - mae_denorm: 1557.4449 - val_loss: 6.3091e-04 - val_mae: 0.0216 - val_mae_denorm: 49.3596
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1057e-06 - mae: 7.5318e-04 - mae_denorm: 1573.4906 - val_loss: 5.4731e-04 - val_mae: 0.0196 - val_mae_denorm: 48.0984
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8039e-07 - mae: 6.0081e-04 - mae_denorm: 1584.1389 - val_loss: 6.5300e-04 - val_mae: 0.0222 - val_mae_denorm: 49.6926
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.3213e-07 - mae: 5.7657e-04 - mae_denorm: 1589.2750 - val_loss: 5.6738e-04 - val_mae: 0.0202 - val_mae_denorm: 48.4123
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.5449e-07 - mae: 5.8817e-04 - mae_denorm: 1612.8923 - val_loss: 4.6712e-04 - val_mae: 0.0176 - val_mae_denorm: 46.8716
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3394e-07 - mae: 6.5612e-04 - mae_denorm: 1591.9658 - val_loss: 5.4985e-04 - val_mae: 0.0199 - val_mae_denorm: 48.1526
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.9811e-07 - mae: 6.0237e-04 - mae_denorm: 1568.9390 - val_loss: 6.0435e-04 - val_mae: 0.0213 - val_mae_denorm: 48.9814
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1823e-06 - mae: 8.0174e-04 - mae_denorm: 1593.4083 - val_loss: 5.7325e-04 - val_mae: 0.0205 - val_mae_denorm: 48.5144
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1340e-07 - mae: 5.6907e-04 - mae_denorm: 1594.1976 - val_loss: 5.4328e-04 - val_mae: 0.0198 - val_mae_denorm: 48.0613
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4236e-07 - mae: 5.3993e-04 - mae_denorm: 1569.8398 - val_loss: 5.1368e-04 - val_mae: 0.0191 - val_mae_denorm: 47.6061
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8216e-07 - mae: 6.1788e-04 - mae_denorm: 1563.7831 - val_loss: 4.4945e-04 - val_mae: 0.0174 - val_mae_denorm: 46.6179
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.7936e-07 - mae: 6.8646e-04 - mae_denorm: 1579.8491 - val_loss: 4.3571e-04 - val_mae: 0.0171 - val_mae_denorm: 46.4071
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.6360e-07 - mae: 7.0935e-04 - mae_denorm: 1548.6200 - val_loss: 5.3085e-04 - val_mae: 0.0196 - val_mae_denorm: 47.8820
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1622e-06 - mae: 8.1868e-04 - mae_denorm: 1573.8053 - val_loss: 4.7903e-04 - val_mae: 0.0183 - val_mae_denorm: 47.0846
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7054e-07 - mae: 5.1491e-04 - mae_denorm: 1554.7932 - val_loss: 5.0875e-04 - val_mae: 0.0191 - val_mae_denorm: 47.5430
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7947e-07 - mae: 6.2217e-04 - mae_denorm: 1561.5001 - val_loss: 4.8722e-04 - val_mae: 0.0186 - val_mae_denorm: 47.2183
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4106e-07 - mae: 6.1459e-04 - mae_denorm: 1579.5431 - val_loss: 4.2456e-04 - val_mae: 0.0168 - val_mae_denorm: 46.2366
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.7513e-07 - mae: 6.6502e-04 - mae_denorm: 1570.0266 - val_loss: 4.4038e-04 - val_mae: 0.0174 - val_mae_denorm: 46.4912
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0820e-06 - mae: 7.7145e-04 - mae_denorm: 1562.9844 - val_loss: 3.7132e-04 - val_mae: 0.0153 - val_mae_denorm: 45.3955
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2483e-06 - mae: 8.3137e-04 - mae_denorm: 1582.7141 - val_loss: 4.7278e-04 - val_mae: 0.0183 - val_mae_denorm: 47.0035
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2014e-07 - mae: 5.5358e-04 - mae_denorm: 1573.4718 - val_loss: 4.0216e-04 - val_mae: 0.0163 - val_mae_denorm: 45.8927
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9179e-07 - mae: 5.9372e-04 - mae_denorm: 1572.6121 - val_loss: 5.3093e-04 - val_mae: 0.0198 - val_mae_denorm: 47.8944
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3394e-06 - mae: 8.6714e-04 - mae_denorm: 1576.6786 - val_loss: 4.9030e-04 - val_mae: 0.0188 - val_mae_denorm: 47.2737
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5218e-07 - mae: 6.5536e-04 - mae_denorm: 1565.0104 - val_loss: 5.6516e-04 - val_mae: 0.0207 - val_mae_denorm: 48.4160
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.7105e-07 - mae: 6.2706e-04 - mae_denorm: 1573.8258 - val_loss: 5.1851e-04 - val_mae: 0.0195 - val_mae_denorm: 47.7074
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8559e-07 - mae: 5.3032e-04 - mae_denorm: 1585.4855 - val_loss: 5.2520e-04 - val_mae: 0.0197 - val_mae_denorm: 47.8113
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8696e-07 - mae: 6.5421e-04 - mae_denorm: 1562.9667 - val_loss: 4.0507e-04 - val_mae: 0.0165 - val_mae_denorm: 45.9474
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2867e-07 - mae: 6.7199e-04 - mae_denorm: 1562.7078 - val_loss: 4.4726e-04 - val_mae: 0.0178 - val_mae_denorm: 46.6142
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4269e-07 - mae: 7.3087e-04 - mae_denorm: 1580.9822 - val_loss: 4.5305e-04 - val_mae: 0.0179 - val_mae_denorm: 46.6977
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1433e-06 - mae: 8.1287e-04 - mae_denorm: 1564.4304 - val_loss: 4.6680e-04 - val_mae: 0.0183 - val_mae_denorm: 46.9133
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3561e-06 - mae: 8.9824e-04 - mae_denorm: 1560.5043 - val_loss: 5.0364e-04 - val_mae: 0.0193 - val_mae_denorm: 47.4910
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8400e-07 - mae: 6.2922e-04 - mae_denorm: 1593.0978 - val_loss: 4.8233e-04 - val_mae: 0.0188 - val_mae_denorm: 47.1625
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5958e-07 - mae: 6.4697e-04 - mae_denorm: 1585.9999 - val_loss: 4.7496e-04 - val_mae: 0.0186 - val_mae_denorm: 47.0529
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4574e-07 - mae: 6.6462e-04 - mae_denorm: 1551.8510 - val_loss: 4.6710e-04 - val_mae: 0.0184 - val_mae_denorm: 46.9264
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8091e-07 - mae: 7.2405e-04 - mae_denorm: 1557.5293 - val_loss: 3.3430e-04 - val_mae: 0.0144 - val_mae_denorm: 44.8178
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2494e-06 - mae: 8.2928e-04 - mae_denorm: 1572.7509 - val_loss: 4.9412e-04 - val_mae: 0.0191 - val_mae_denorm: 47.3412
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0973e-06 - mae: 7.9180e-04 - mae_denorm: 1596.4960 - val_loss: 3.4660e-04 - val_mae: 0.0149 - val_mae_denorm: 45.0259
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9696e-07 - mae: 5.8916e-04 - mae_denorm: 1563.0031 - val_loss: 4.2993e-04 - val_mae: 0.0174 - val_mae_denorm: 46.3534
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0200e-07 - mae: 5.0258e-04 - mae_denorm: 1565.2654 - val_loss: 4.7433e-04 - val_mae: 0.0186 - val_mae_denorm: 47.0454
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2147e-06 - mae: 8.4624e-04 - mae_denorm: 1576.8137 - val_loss: 3.2964e-04 - val_mae: 0.0144 - val_mae_denorm: 44.7573
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7871e-06 - mae: 9.8368e-04 - mae_denorm: 1557.5142 - val_loss: 5.9223e-04 - val_mae: 0.0215 - val_mae_denorm: 48.8305
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8640e-06 - mae: 0.0010 - mae_denorm: 1569.2865 - val_loss: 3.1762e-04 - val_mae: 0.0139 - val_mae_denorm: 44.5484
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8607e-06 - mae: 0.0013 - mae_denorm: 1584.8293 - val_loss: 4.4979e-04 - val_mae: 0.0180 - val_mae_denorm: 46.6639
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9239e-07 - mae: 7.1480e-04 - mae_denorm: 1570.7399 - val_loss: 4.2576e-04 - val_mae: 0.0173 - val_mae_denorm: 46.2836
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4732e-07 - mae: 5.7809e-04 - mae_denorm: 1581.2466 - val_loss: 3.9323e-04 - val_mae: 0.0164 - val_mae_denorm: 45.7801
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8396e-07 - mae: 6.8449e-04 - mae_denorm: 1564.9989 - val_loss: 4.4032e-04 - val_mae: 0.0178 - val_mae_denorm: 46.5270
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2112e-06 - mae: 8.2941e-04 - mae_denorm: 1577.2009 - val_loss: 4.3741e-04 - val_mae: 0.0177 - val_mae_denorm: 46.4762
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4100e-07 - mae: 5.8088e-04 - mae_denorm: 1563.8879 - val_loss: 4.4164e-04 - val_mae: 0.0179 - val_mae_denorm: 46.5440
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2118e-06 - mae: 0.0011 - mae_denorm: 1565.5028 - val_loss: 5.4674e-04 - val_mae: 0.0205 - val_mae_denorm: 48.1555
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0628e-06 - mae: 0.0013 - mae_denorm: 1585.3491 - val_loss: 3.8576e-04 - val_mae: 0.0163 - val_mae_denorm: 45.6661
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0362e-06 - mae: 7.8643e-04 - mae_denorm: 1576.9766 - val_loss: 3.9405e-04 - val_mae: 0.0165 - val_mae_denorm: 45.7955
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2762e-06 - mae: 8.4318e-04 - mae_denorm: 1605.3322 - val_loss: 4.3661e-04 - val_mae: 0.0177 - val_mae_denorm: 46.4664
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0643e-06 - mae: 0.0012 - mae_denorm: 1575.5424 - val_loss: 3.1655e-04 - val_mae: 0.0142 - val_mae_denorm: 44.5664
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5642e-06 - mae: 0.0017 - mae_denorm: 1569.0983 - val_loss: 4.2575e-04 - val_mae: 0.0174 - val_mae_denorm: 46.2869
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9643e-07 - mae: 5.9252e-04 - mae_denorm: 1575.3109 - val_loss: 3.8264e-04 - val_mae: 0.0162 - val_mae_denorm: 45.6177
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8022e-07 - mae: 6.8281e-04 - mae_denorm: 1587.7216 - val_loss: 4.1945e-04 - val_mae: 0.0173 - val_mae_denorm: 46.1981
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4782e-07 - mae: 6.2919e-04 - mae_denorm: 1561.9834 - val_loss: 3.8934e-04 - val_mae: 0.0164 - val_mae_denorm: 45.7274
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5487e-07 - mae: 6.5529e-04 - mae_denorm: 1593.6260 - val_loss: 4.2087e-04 - val_mae: 0.0174 - val_mae_denorm: 46.2238
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4845e-07 - mae: 6.5828e-04 - mae_denorm: 1553.6177 - val_loss: 3.6481e-04 - val_mae: 0.0157 - val_mae_denorm: 45.3349
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5339e-07 - mae: 5.7323e-04 - mae_denorm: 1564.2682 - val_loss: 4.1494e-04 - val_mae: 0.0172 - val_mae_denorm: 46.1269
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0635e-06 - mae: 7.5184e-04 - mae_denorm: 1563.6312 - val_loss: 3.4469e-04 - val_mae: 0.0151 - val_mae_denorm: 45.0138
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7182e-06 - mae: 0.0010 - mae_denorm: 1566.0505 - val_loss: 4.1372e-04 - val_mae: 0.0172 - val_mae_denorm: 46.1153
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9438e-06 - mae: 0.0015 - mae_denorm: 1567.7054 - val_loss: 3.5812e-04 - val_mae: 0.0156 - val_mae_denorm: 45.2332
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5200e-06 - mae: 0.0012 - mae_denorm: 1575.2328 - val_loss: 4.5497e-04 - val_mae: 0.0184 - val_mae_denorm: 46.7615
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.7424e-07 - mae: 7.5864e-04 - mae_denorm: 1569.4890 - val_loss: 3.4884e-04 - val_mae: 0.0153 - val_mae_denorm: 45.0848
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0187e-07 - mae: 5.8621e-04 - mae_denorm: 1569.6034 - val_loss: 4.3394e-04 - val_mae: 0.0178 - val_mae_denorm: 46.4336
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5001e-07 - mae: 5.6942e-04 - mae_denorm: 1578.9691 - val_loss: 3.5331e-04 - val_mae: 0.0154 - val_mae_denorm: 45.1575
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7104e-07 - mae: 6.2274e-04 - mae_denorm: 1596.4856 - val_loss: 4.9677e-04 - val_mae: 0.0195 - val_mae_denorm: 47.4037
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3071e-06 - mae: 8.7738e-04 - mae_denorm: 1567.7118 - val_loss: 3.3361e-04 - val_mae: 0.0148 - val_mae_denorm: 44.8354
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2746e-06 - mae: 8.7910e-04 - mae_denorm: 1573.0209 - val_loss: 4.5835e-04 - val_mae: 0.0185 - val_mae_denorm: 46.8115
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0443e-06 - mae: 7.7899e-04 - mae_denorm: 1560.4844 - val_loss: 3.2372e-04 - val_mae: 0.0145 - val_mae_denorm: 44.6814
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.6852e-07 - mae: 6.1593e-04 - mae_denorm: 1568.0106 - val_loss: 4.0524e-04 - val_mae: 0.0170 - val_mae_denorm: 45.9851
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0900e-07 - mae: 5.0029e-04 - mae_denorm: 1566.7782 - val_loss: 3.4699e-04 - val_mae: 0.0154 - val_mae_denorm: 45.0680
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.1866e-07 - mae: 7.1459e-04 - mae_denorm: 1583.9833 - val_loss: 4.7161e-04 - val_mae: 0.0189 - val_mae_denorm: 47.0206
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9516e-06 - mae: 0.0011 - mae_denorm: 1572.3441 - val_loss: 3.3726e-04 - val_mae: 0.0150 - val_mae_denorm: 44.9056
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1021e-07 - mae: 6.2511e-04 - mae_denorm: 1587.6179 - val_loss: 2.2745e-04 - val_mae: 0.0113 - val_mae_denorm: 43.0760
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5531e-06 - mae: 0.0011 - mae_denorm: 1589.0370 - val_loss: 4.0823e-04 - val_mae: 0.0172 - val_mae_denorm: 46.0399
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0506e-06 - mae: 7.5868e-04 - mae_denorm: 1585.1279 - val_loss: 4.2296e-04 - val_mae: 0.0176 - val_mae_denorm: 46.2687
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7744e-07 - mae: 6.3244e-04 - mae_denorm: 1591.2826 - val_loss: 5.2400e-04 - val_mae: 0.0203 - val_mae_denorm: 47.8255
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9173e-06 - mae: 0.0017 - mae_denorm: 1560.3873 - val_loss: 3.2751e-04 - val_mae: 0.0145 - val_mae_denorm: 44.7286
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1910e-06 - mae: 8.3409e-04 - mae_denorm: 1595.9075 - val_loss: 3.0823e-04 - val_mae: 0.0141 - val_mae_denorm: 44.4354
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1814e-07 - mae: 6.3839e-04 - mae_denorm: 1572.5955 - val_loss: 4.6089e-04 - val_mae: 0.0187 - val_mae_denorm: 46.8610
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1376e-06 - mae: 0.0011 - mae_denorm: 1569.5907 - val_loss: 3.1884e-04 - val_mae: 0.0145 - val_mae_denorm: 44.6159
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9120e-07 - mae: 5.4736e-04 - mae_denorm: 1560.7566 - val_loss: 3.7368e-04 - val_mae: 0.0162 - val_mae_denorm: 45.4882
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.7954e-07 - mae: 6.5421e-04 - mae_denorm: 1545.4447 - val_loss: 3.1007e-04 - val_mae: 0.0142 - val_mae_denorm: 44.4722
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.3772e-07 - mae: 7.5290e-04 - mae_denorm: 1599.9122 - val_loss: 3.4340e-04 - val_mae: 0.0153 - val_mae_denorm: 45.0053
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7104e-06 - mae: 9.9755e-04 - mae_denorm: 1573.4927 - val_loss: 3.6057e-04 - val_mae: 0.0158 - val_mae_denorm: 45.2828
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6819e-06 - mae: 9.5976e-04 - mae_denorm: 1569.8715 - val_loss: 3.8671e-04 - val_mae: 0.0166 - val_mae_denorm: 45.7003
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1230e-06 - mae: 8.2589e-04 - mae_denorm: 1566.0209 - val_loss: 3.4039e-04 - val_mae: 0.0152 - val_mae_denorm: 44.9626
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8973e-07 - mae: 5.4556e-04 - mae_denorm: 1565.1189 - val_loss: 3.0152e-04 - val_mae: 0.0139 - val_mae_denorm: 44.3326
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8110e-07 - mae: 5.3495e-04 - mae_denorm: 1550.7668 - val_loss: 3.3078e-04 - val_mae: 0.0149 - val_mae_denorm: 44.8099
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4703e-07 - mae: 6.0946e-04 - mae_denorm: 1589.9684 - val_loss: 3.4887e-04 - val_mae: 0.0155 - val_mae_denorm: 45.1017
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6844e-07 - mae: 5.3187e-04 - mae_denorm: 1589.0205 - val_loss: 3.7442e-04 - val_mae: 0.0164 - val_mae_denorm: 45.5130
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0562e-07 - mae: 5.5042e-04 - mae_denorm: 1573.8021 - val_loss: 3.6203e-04 - val_mae: 0.0159 - val_mae_denorm: 45.3112
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1737e-06 - mae: 8.2190e-04 - mae_denorm: 1588.2843 - val_loss: 2.9416e-04 - val_mae: 0.0137 - val_mae_denorm: 44.2145
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2402e-06 - mae: 0.0011 - mae_denorm: 1574.5952 - val_loss: 3.4723e-04 - val_mae: 0.0155 - val_mae_denorm: 45.0735
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2882e-06 - mae: 0.0010 - mae_denorm: 1576.4851 - val_loss: 3.1399e-04 - val_mae: 0.0145 - val_mae_denorm: 44.5467
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6247e-07 - mae: 5.3482e-04 - mae_denorm: 1586.3064 - val_loss: 3.6453e-04 - val_mae: 0.0160 - val_mae_denorm: 45.3514
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8584e-07 - mae: 5.4052e-04 - mae_denorm: 1573.4133 - val_loss: 2.8091e-04 - val_mae: 0.0133 - val_mae_denorm: 44.0016
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7269e-06 - mae: 9.6254e-04 - mae_denorm: 1554.6102 - val_loss: 2.6258e-04 - val_mae: 0.0126 - val_mae_denorm: 43.6957
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3295e-06 - mae: 8.6131e-04 - mae_denorm: 1568.1226 - val_loss: 3.9579e-04 - val_mae: 0.0171 - val_mae_denorm: 45.8552
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7863e-07 - mae: 6.1958e-04 - mae_denorm: 1553.9708 - val_loss: 3.0360e-04 - val_mae: 0.0141 - val_mae_denorm: 44.3763
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2510e-07 - mae: 5.5085e-04 - mae_denorm: 1575.3889 - val_loss: 3.2385e-04 - val_mae: 0.0148 - val_mae_denorm: 44.7043
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1262e-06 - mae: 8.2112e-04 - mae_denorm: 1566.7238 - val_loss: 3.1595e-04 - val_mae: 0.0146 - val_mae_denorm: 44.5811
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0150e-06 - mae: 7.3779e-04 - mae_denorm: 1560.7063 - val_loss: 4.0166e-04 - val_mae: 0.0173 - val_mae_denorm: 45.9511
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.2122e-07 - mae: 7.1049e-04 - mae_denorm: 1574.7960 - val_loss: 1.9108e-04 - val_mae: 0.0103 - val_mae_denorm: 42.4746
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3703e-06 - mae: 0.0011 - mae_denorm: 1563.0961 - val_loss: 3.7251e-04 - val_mae: 0.0164 - val_mae_denorm: 45.4901
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8102e-07 - mae: 5.7843e-04 - mae_denorm: 1560.5436 - val_loss: 2.7301e-04 - val_mae: 0.0131 - val_mae_denorm: 43.8763
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.5406e-07 - mae: 7.6128e-04 - mae_denorm: 1582.5542 - val_loss: 3.8094e-04 - val_mae: 0.0167 - val_mae_denorm: 45.6267
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0017e-07 - mae: 6.2565e-04 - mae_denorm: 1579.2137 - val_loss: 4.1555e-04 - val_mae: 0.0176 - val_mae_denorm: 46.1606
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8026e-07 - mae: 5.7609e-04 - mae_denorm: 1543.1324 - val_loss: 3.1232e-04 - val_mae: 0.0146 - val_mae_denorm: 44.5303
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4349e-07 - mae: 6.5272e-04 - mae_denorm: 1568.4119 - val_loss: 2.7268e-04 - val_mae: 0.0132 - val_mae_denorm: 43.8790
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5534e-07 - mae: 6.6369e-04 - mae_denorm: 1584.9330 - val_loss: 3.2095e-04 - val_mae: 0.0148 - val_mae_denorm: 44.6634
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2356e-06 - mae: 7.8972e-04 - mae_denorm: 1560.6538 - val_loss: 3.0076e-04 - val_mae: 0.0142 - val_mae_denorm: 44.3455
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3760e-06 - mae: 8.5580e-04 - mae_denorm: 1553.4753 - val_loss: 3.5645e-04 - val_mae: 0.0160 - val_mae_denorm: 45.2374
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2276e-06 - mae: 8.3502e-04 - mae_denorm: 1552.2139 - val_loss: 2.7538e-04 - val_mae: 0.0134 - val_mae_denorm: 43.9330
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7040e-06 - mae: 0.0013 - mae_denorm: 1564.3894 - val_loss: 2.0660e-04 - val_mae: 0.0109 - val_mae_denorm: 42.7799
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9677e-06 - mae: 0.0018 - mae_denorm: 1580.5143 - val_loss: 3.7879e-04 - val_mae: 0.0167 - val_mae_denorm: 45.5922
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7626e-06 - mae: 0.0010 - mae_denorm: 1550.6487 - val_loss: 2.7357e-04 - val_mae: 0.0133 - val_mae_denorm: 43.9076
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.9599e-07 - mae: 7.6834e-04 - mae_denorm: 1555.0042 - val_loss: 2.7041e-04 - val_mae: 0.0131 - val_mae_denorm: 43.8446
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8933e-06 - mae: 9.8507e-04 - mae_denorm: 1587.6146 - val_loss: 3.7441e-04 - val_mae: 0.0166 - val_mae_denorm: 45.5297
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.6284e-07 - mae: 7.2648e-04 - mae_denorm: 1600.1445 - val_loss: 3.2337e-04 - val_mae: 0.0151 - val_mae_denorm: 44.7209

# %%
# Plot training & validation loss values
plt.figure(figsize=(15,5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss: mean squared error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Plot training & validation mae values
plt.figure(figsize=(15,5))
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('Model metric: MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Plot training & validation mae_denorm values
plt.figure(figsize=(15,5))
plt.plot(hist.history['mae_denorm'])
plt.plot(hist.history['val_mae_denorm'])
plt.title('Model metric: MAE denorm')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train_denorm', 'val_denorm'], loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# # 5. Evaluate the model

# %%
# Load the model from the best epoch (minimum val_loss)
import os
bestmodel_path = max( [ f for f in os.listdir(".") if f.startswith('LSTM_ex1_bestmodel_') and f.endswith(".keras") ] )
print( f"The best model: {bestmodel_path}" )

model_best = keras.models.load_model(bestmodel_path, compile=True)
# Out:
# The best model: LSTM_ex1_bestmodel_epoch284.keras

# %%
# Evaluate the model from the last epoch
score = model.evaluate( x_test_norm, y_test_norm, verbose=0, return_dict=True )
print( "Test results (model from the last epoch):", score )

# Evaluate the model from the best epoch
score = model_best.evaluate( x_test_norm, y_test_norm, verbose=0, return_dict=True )
print( "Test results (model from the best epoch):", score )
# Out:
# Test results (model from the last epoch): {'loss': 0.007501705549657345, 'mae': 0.08125415444374084, 'mae_denorm': 117.42999267578125}
# Test results (model from the best epoch): {'loss': 0.006906526163220406, 'mae': 0.07724644988775253, 'mae_denorm': 111.98873138427734}

# %% [markdown]
# # 6. Inference

# %%
# Batch prediction
y_pred_norm = model.predict( x_test_norm )        # Model from the last epoch
y2_pred_norm = model_best.predict( x_test_norm )  # Model from the best epoch

# Denormalize using training statistics
y_pred = (y_pred_norm * train_std) + train_mean
y2_pred = (y2_pred_norm * train_std) + train_mean

# Show prediction results of the first n data in the test set
n = 20
for i in range( n ):
    print( f"x_test[{i}] = {x_test[i].reshape(1,-1)}" )
    print( f"y_test[{i}] = {y_test[i]}" )
    print( f"y_pred_last_epoch[{i}] = {y_pred[i]} =round=> {np.around( y_pred[i] )}" )
    print( f"y_pred_best_epoch[{i}] = {y2_pred[i]} =round=> {np.around(y2_pred[i])}\n" )
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# x_test[0] = [[1392 1394 1396 1398 1400]]
# y_test[0] = 1402
# y_pred_last_epoch[0] = [1351.36195797] =round=> [1351.]
# y_pred_best_epoch[0] = [1358.34780223] =round=> [1358.]
#
# x_test[1] = [[1394 1396 1398 1400 1402]]
# y_test[1] = 1404
# y_pred_last_epoch[1] = [1353.06794963] =round=> [1353.]
# y_pred_best_epoch[1] = [1360.04652593] =round=> [1360.]
#
# x_test[2] = [[1396 1398 1400 1402 1404]]
# y_test[2] = 1406
# y_pred_last_epoch[2] = [1354.77261985] =round=> [1355.]
# y_pred_best_epoch[2] = [1361.74392817] =round=> [1362.]
#
# x_test[3] = [[1398 1400 1402 1404 1406]]
# y_test[3] = 1408
# y_pred_last_epoch[3] = [1356.47662934] =round=> [1356.]
# y_pred_best_epoch[3] = [1363.44000897] =round=> [1363.]
#
# x_test[4] = [[1400 1402 1404 1406 1408]]
# y_test[4] = 1410
# y_pred_last_epoch[4] = [1358.17931739] =round=> [1358.]
# y_pred_best_epoch[4] = [1365.13542903] =round=> [1365.]
#
# x_test[5] = [[1402 1404 1406 1408 1410]]
# y_test[5] = 1412
# y_pred_last_epoch[5] = [1359.88068398] =round=> [1360.]
# y_pred_best_epoch[5] = [1366.82952765] =round=> [1367.]
#
# x_test[6] = [[1404 1406 1408 1410 1412]]
# y_test[6] = 1414
# y_pred_last_epoch[6] = [1361.58138985] =round=> [1362.]
# y_pred_best_epoch[6] = [1368.52230482] =round=> [1369.]
#
# x_test[7] = [[1406 1408 1410 1412 1414]]
# y_test[7] = 1416
# y_pred_last_epoch[7] = [1363.28077427] =round=> [1363.]
# y_pred_best_epoch[7] = [1370.21376054] =round=> [1370.]
#
# x_test[8] = [[1408 1410 1412 1414 1416]]
# y_test[8] = 1418
# y_pred_last_epoch[8] = [1364.97883724] =round=> [1365.]
# y_pred_best_epoch[8] = [1371.90455554] =round=> [1372.]
#
# x_test[9] = [[1410 1412 1414 1416 1418]]
# y_test[9] = 1420
# y_pred_last_epoch[9] = [1366.67557875] =round=> [1367.]
# y_pred_best_epoch[9] = [1373.59402908] =round=> [1374.]
#
# x_test[10] = [[1412 1414 1416 1418 1420]]
# y_test[10] = 1422
# y_pred_last_epoch[10] = [1368.37198991] =round=> [1368.]
# y_pred_best_epoch[10] = [1375.28251154] =round=> [1375.]
#
# x_test[11] = [[1414 1416 1418 1420 1422]]
# y_test[11] = 1424
# y_pred_last_epoch[11] = [1370.06674926] =round=> [1370.]
# y_pred_best_epoch[11] = [1376.96934219] =round=> [1377.]
#
# x_test[12] = [[1416 1418 1420 1422 1424]]
# y_test[12] = 1426
# y_pred_last_epoch[12] = [1371.76051751] =round=> [1372.]
# y_pred_best_epoch[12] = [1378.65518175] =round=> [1379.]
#
# x_test[13] = [[1418 1420 1422 1424 1426]]
# y_test[13] = 1428
# y_pred_last_epoch[13] = [1373.45263396] =round=> [1373.]
# y_pred_best_epoch[13] = [1380.34069094] =round=> [1380.]
#
# x_test[14] = [[1420 1422 1424 1426 1428]]
# y_test[14] = 1430
# y_pred_last_epoch[14] = [1375.1447504] =round=> [1375.]
# y_pred_best_epoch[14] = [1382.02421796] =round=> [1382.]
#
# x_test[15] = [[1422 1424 1426 1428 1430]]
# y_test[15] = 1432
# y_pred_last_epoch[15] = [1376.83488467] =round=> [1377.]
# y_pred_best_epoch[15] = [1383.7067539] =round=> [1384.]
#
# x_test[16] = [[1424 1426 1428 1430 1432]]
# y_test[16] = 1434
# y_pred_last_epoch[16] = [1378.52402786] =round=> [1379.]
# y_pred_best_epoch[16] = [1385.38796838] =round=> [1385.]
#
# x_test[17] = [[1426 1428 1430 1432 1434]]
# y_test[17] = 1436
# y_pred_last_epoch[17] = [1380.21217995] =round=> [1380.]
# y_pred_best_epoch[17] = [1387.06819178] =round=> [1387.]
#
# x_test[18] = [[1428 1430 1432 1434 1436]]
# y_test[18] = 1438
# y_pred_last_epoch[18] = [1381.89934096] =round=> [1382.]
# y_pred_best_epoch[18] = [1388.74709373] =round=> [1389.]
#
# x_test[19] = [[1430 1432 1434 1436 1438]]
# y_test[19] = 1440
# y_pred_last_epoch[19] = [1383.58485015] =round=> [1384.]
# y_pred_best_epoch[19] = [1390.42533495] =round=> [1390.]
