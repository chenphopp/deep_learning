# %% [markdown]
# # 1. Prepare the environment

# %%
# List all NVIDIA GPUs as available in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-5482509f-1248-3ce7-acb6-84ed23b69f54)

# %%
import sys
print( f"Python {sys.version}\n" )

import pandas as pd
print( f"Pandas {pd.__version__}\n" )

import numpy as np
print( f"NumPy {np.__version__}\n" )

import matplotlib.pyplot as plt
# %matplotlib inline

# https://keras.io/getting_started/
# The backend must be configured before importing Keras, and the backend cannot be changed after the package has been imported.
import os
os.environ["KERAS_BACKEND"] = "torch"  # "jax", "tensorflow"

import keras
print(f"Keras {keras.__version__}")
print(f"|- Keras backend = {keras.backend.backend()}")
print(f"|- Keras backend image data format = {keras.backend.image_data_format()}\n")

import torch
print( f"PyTorch {torch.__version__}" )

# Get all available accelerators such as CUDA, MPS, MTIA, or XPU
num_accelerators = torch.accelerator.device_count()

if (num_accelerators <= 0):
    print("|- No hardware accelerators found. Using CPU only.")
else:
    print(f"|- PyTorch detected {num_accelerators} hardware accelerator(s)")
    print(f"|- PyTorch detected '{torch.accelerator.current_accelerator().type.upper()}' as the current accelerator")

    # Check cuda availability
    if torch.cuda.is_available():
        num_gpus = torch.cuda.device_count()
        print(f"|- PyTorch detected {num_gpus} CUDA GPU(s):")
    for i in range(num_gpus):
        print(f"   |- CUDA GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
#
# Pandas 2.2.2
#
# NumPy 2.0.2
#
# Keras 3.10.0
# |- Keras backend = torch
# |- Keras backend image data format = channels_last
#
# PyTorch 2.6.0+cu124
# |- PyTorch detected 1 hardware accelerator(s)
# |- PyTorch detected 'CUDA' as the current accelerator
# |- PyTorch detected 1 CUDA GPU(s):
#    |- CUDA GPU 0: Tesla T4

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed

# https://keras.io/examples/keras_recipes/reproducibility_recipes/
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
#keras.utils.set_random_seed(1234)

# %% [markdown]
# # 2. Prepare the dataset
#
# Load the Boston Housing dataset (http://lib.stat.cmu.edu/datasets/boston) from Keras

# %%
# Load
(x_train, y_train), (x_test, y_test) = keras.datasets.boston_housing.load_data()

# Inspect
vars = [ ('x_train',x_train), ('y_train',y_train), ('x_test',x_test), ('y_test',y_test) ]
for name,var in vars:
  print(f"{name}: type={type(var)} , shape={var.shape} , dtype={var.dtype}")
# Out:
# x_train: type=<class 'numpy.ndarray'> , shape=(404, 13) , dtype=float64
# y_train: type=<class 'numpy.ndarray'> , shape=(404,) , dtype=float64
# x_test: type=<class 'numpy.ndarray'> , shape=(102, 13) , dtype=float64
# y_test: type=<class 'numpy.ndarray'> , shape=(102,) , dtype=float64

# %% [markdown]
# (Optional) Preview the train and test sets with pandas' dataframe

# %%
# A function to convert two numpy arrays to a single dataframe
def boston_dataframe(np_x, np_y):
  # Create a dataframe from two numpy arrays
  columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
  df_boston = pd.DataFrame(np_x, columns=columns)   # 13 feature columns
  df_boston['MEDV'] = pd.Series(np_y)   # 1 output column

  return df_boston

# Preview stats regarding both train and test datasets
print('===== PREVIEW: THE TRAIN SET =====')
display( boston_dataframe(x_train, y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: THE TEST SET =====')
display( boston_dataframe(x_test, y_test).describe().style.format(precision=2) )
# Out:
# ===== PREVIEW: THE TRAIN SET =====
# <style type="text/css">
# </style>
# <table id="T_48e12" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48e12_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_48e12_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_48e12_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_48e12_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_48e12_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_48e12_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_48e12_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_48e12_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_48e12_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_48e12_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_48e12_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_48e12_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_48e12_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_48e12_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48e12_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_48e12_row0_col0" class="data row0 col0" >404.00</td>
#       <td id="T_48e12_row0_col1" class="data row0 col1" >404.00</td>
#       <td id="T_48e12_row0_col2" class="data row0 col2" >404.00</td>
#       <td id="T_48e12_row0_col3" class="data row0 col3" >404.00</td>
#       <td id="T_48e12_row0_col4" class="data row0 col4" >404.00</td>
#       <td id="T_48e12_row0_col5" class="data row0 col5" >404.00</td>
#       <td id="T_48e12_row0_col6" class="data row0 col6" >404.00</td>
#       <td id="T_48e12_row0_col7" class="data row0 col7" >404.00</td>
#       <td id="T_48e12_row0_col8" class="data row0 col8" >404.00</td>
#       <td id="T_48e12_row0_col9" class="data row0 col9" >404.00</td>
#       <td id="T_48e12_row0_col10" class="data row0 col10" >404.00</td>
#       <td id="T_48e12_row0_col11" class="data row0 col11" >404.00</td>
#       <td id="T_48e12_row0_col12" class="data row0 col12" >404.00</td>
#       <td id="T_48e12_row0_col13" class="data row0 col13" >404.00</td>
#     </tr>
#     <tr>
#       <th id="T_48e12_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_48e12_row1_col0" class="data row1 col0" >3.75</td>
#       <td id="T_48e12_row1_col1" class="data row1 col1" >11.48</td>
#       <td id="T_48e12_row1_col2" class="data row1 col2" >11.10</td>
#       <td id="T_48e12_row1_col3" class="data row1 col3" >0.06</td>
#       <td id="T_48e12_row1_col4" class="data row1 col4" >0.56</td>
#       <td id="T_48e12_row1_col5" class="data row1 col5" >6.27</td>
#       <td id="T_48e12_row1_col6" class="data row1 col6" >69.01</td>
#       <td id="T_48e12_row1_col7" class="data row1 col7" >3.74</td>
level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_48e12_row5_col0" class="data row5 col0" >0.27</td>
#       <td id="T_48e12_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_48e12_row5_col2" class="data row5 col2" >9.69</td>
#       <td id="T_48e12_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_48e12_row5_col4" class="data row5 col4" >0.54</td>
#       <td id="T_48e12_row5_col5" class="data row5 col5" >6.20</td>
#       <td id="T_48e12_row5_col6" class="data row5 col6" >78.50</td>
#       <td id="T_48e12_row5_col7" class="data row5 col7" >3.14</td>
#       <td id="T_48e12_row5_col8" class="data row5 col8" >5.00</td>
#       <td id="T_48e12_row5_col9" class="data row5 col9" >330.00</td>
#       <td id="T_48e12_row5_col10" class="data row5 col10" >19.10</td>
#       <td id="T_48e12_row5_col11" class="data row5 col11" >391.25</td>
#       <td id="T_48e12_row5_col12" class="data row5 col12" >11.39</td>
#       <td id="T_48e12_row5_col13" class="data row5 col13" >20.75</td>
#     </tr>
#     <tr>
#       <th id="T_48e12_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_48e12_row6_col0" class="data row6 col0" >3.67</td>
#       <td id="T_48e12_row6_col1" class="data row6 col1" >12.50</td>
#       <td id="T_48e12_row6_col2" class="data row6 col2" >18.10</td>
#       <td id="T_48e12_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_48e12_row6_col4" class="data row6 col4" >0.63</td>
# ===== PREVIEW: THE TEST SET =====
# <style type="text/css">
# </style>
# <table id="T_3ac48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ac48_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_3ac48_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_3ac48_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_3ac48_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_3ac48_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_3ac48_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_3ac48_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_3ac48_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_3ac48_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_3ac48_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_3ac48_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_3ac48_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_3ac48_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_3ac48_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ac48_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3ac48_row0_col0" class="data row0 col0" >102.00</td>
#       <td id="T_3ac48_row0_col1" class="data row0 col1" >102.00</td>
#       <td id="T_3ac48_row0_col2" class="data row0 col2" >102.00</td>
#       <td id="T_3ac48_row0_col3" class="data row0 col3" >102.00</td>
#       <td id="T_3ac48_row0_col4" class="data row0 col4" >102.00</td>
#       <td id="T_3ac48_row0_col5" class="data row0 col5" >102.00</td>
#       <td id="T_3ac48_row0_col6" class="data row0 col6" >102.00</td>
#       <td id="T_3ac48_row0_col7" class="data row0 col7" >102.00</td>
#       <td id="T_3ac48_row0_col8" class="data row0 col8" >102.00</td>
#       <td id="T_3ac48_row0_col9" class="data row0 col9" >102.00</td>
#       <td id="T_3ac48_row0_col10" class="data row0 col10" >102.00</td>
#       <td id="T_3ac48_row0_col11" class="data row0 col11" >102.00</td>
#       <td id="T_3ac48_row0_col12" class="data row0 col12" >102.00</td>
#       <td id="T_3ac48_row0_col13" class="data row0 col13" >102.00</td>
#     </tr>
#     <tr>
#       <th id="T_3ac48_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_3ac48_row1_col0" class="data row1 col0" >3.09</td>
#       <td id="T_3ac48_row1_col1" class="data row1 col1" >10.90</td>
#       <td id="T_3ac48_row1_col2" class="data row1 col2" >11.26</td>
#       <td id="T_3ac48_row1_col3" class="data row1 col3" >0.10</td>
#       <td id="T_3ac48_row1_col4" class="data row1 col4" >0.54</td>
#       <td id="T_3ac48_row1_col5" class="data row1 col5" >6.35</td>
#       <td id="T_3ac48_row1_col6" class="data row1 col6" >66.85</td>
#       <td id="T_3ac48_row1_col7" class="data row1 col7" >4.01</td>
#       <td id="T_3ac48_row1_col8" class="data row1 col8" >9.98</td>
#       <td id="T_3ac48_row1_col9" class="data row1 col9" >417.50</td>
#       <td id="T_3ac48_row1_col10" class="data row1 col10" >18.37</td>
#       <td id="T_3ac48_row1_col11" class="data row1 col11" >364.16</td>
#       <td id="T_3ac48_row1_col12" class="data row1 col12" >12.31</td>
#       <td id="T_3ac48_row1_col13" class="data row1 col13" >23.08</td>
#     </tr>
#     <tr>
#       <th id="T_3ac48_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_3ac48_row2_col0" class="data row2 col0" >5.37</td>
#       <td id="T_3ac48_row2_col1" class="data row2 col1" >21.57</td>
#       <td id="T_3ac48_row2_col2" class="data row2 col2" >7.08</td>
#       <td id="T_3ac48_row2_col3" class="data row2 col3" >0.30</td>
#       <td id="T_3ac48_row2_col4" class="data row2 col4" >0.11</td>
#       <td id="T_3ac48_row2_col5" class="data row2 col5" >0.67</td>
#       <td id="T_3ac48_row2_col6" class="data row2 col6" >29.03</td>
#       <td id="T_3ac48_row2_col7" class="data row2 col7" >2.38</td>
#       <td id="T_3ac48_row2_col8" class="data row2 col8" >8.77</td>
#       <td id="T_3ac48_row2_col9" class="data row2 col9" >177.39</td>
#       <td id="T_3ac48_row2_col10" class="data row2 col10" >2.03</td>
#       <td id="T_3ac48_row2_col11" class="data row2 col11" >79.14</td>
#       <td id="T_3ac48_row2_col12" class="data row2 col12" >6.70</td>
#       <td id="T_3ac48_row2_col13" class="data row2 col13" >9.17</td>
#     </tr>
#     <tr>
#       <th id="T_3ac48_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_3ac48_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_3ac48_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_3ac48_row3_col2" class="data row3 col2" >1.22</td>
#       <td id="T_3ac48_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T
level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_3ac48_row6_col0" class="data row6 col0" >3.78</td>
#       <td id="T_3ac48_row6_col1" class="data row6 col1" >16.25</td>
#       <td id="T_3ac48_row6_col2" class="data row6 col2" >18.10</td>
#       <td id="T_3ac48_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_3ac48_row6_col4" class="data row6 col4" >0.61</td>

# %% [markdown]
# Normalize each feature separately

# %%
# Compute means and SDs from *the train set*
# 'axis' = Axis or axes along which the means are computed. The default is to compute the mean of the flattened array.
mean = x_train.mean(axis=0)   # https://numpy.org/doc/stable/reference/generated/numpy.mean.html
sd = x_train.std(axis=0)      # https://numpy.org/doc/stable/reference/generated/numpy.std.html
print(f"{mean.shape=} , {sd.shape=}\n")

# Normalize 13 features
x_train_norm = ( x_train - mean ) / sd
x_test_norm = ( x_test - mean ) / sd

# Inspect
print('===== PREVIEW: TRAIN SET AFTER NORM =====')
display( boston_dataframe(x_train_norm, y_train).describe().style.format(precision=2) )
print('\n===== PREVIEW: TEST SET AFTER NORM =====')
display( boston_dataframe(x_test_norm, y_test).describe().style.format(precision=2) )
# Out:
# mean.shape=(13,) , sd.shape=(13,)
#
# ===== PREVIEW: TRAIN SET AFTER NORM =====
# <style type="text/css">
# </style>
# <table id="T_3098a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3098a_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_3098a_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_3098a_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_3098a_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_3098a_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_3098a_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_3098a_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_3098a_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_3098a_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_3098a_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_3098a_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_3098a_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_3098a_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_3098a_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3098a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3098a_row0_col0" class="data row0 col0" >404.00</td>
#       <td id="T_3098a_row0_col1" class="data row0 col1" >404.00</td>
#       <td id="T_3098a_row0_col2" class="data row0 col2" >404.00</td>
#       <td id="T_3098a_row0_col3" class="data row0 col3" >404.00</td>
#       <td id="T_3098a_row0_col4" class="data row0 col4" >404.00</td>
#       <td id="T_3098a_row0_col5" class="data row0 col5" >404.00</td>
#       <td id="T_3098a_row0_col6" class="data row0 col6" >404.00</td>
#       <td id="T_3098a_row0_col7" class="data row0 col7" >404.00</td>
#       <td id="T_3098a_row0_col8" class="data row0 col8" >404.00</td>
#       <td id="T_3098a_row0_col9" class="data row0 col9" >404.00</td>
#       <td id="T_3098a_row0_col10" class="data row0 col10" >404.00</td>
#       <td id="T_3098a_row0_col11" class="data row0 col11" >404.00</td>
#       <td id="T_3098a_row0_col12" class="data row0 col12" >404.00</td>
#       <td id="T_3098a_row0_col13" class="data row0 col13" >404.00</td>
#     </tr>
#     <tr>
#       <th id="T_3098a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T
level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_3098a_row4_col0" class="data row4 col0" >-0.40</td>
#       <td id="T_3098a_row4_col1" class="data row4 col1" >-0.48</td>
#       <td id="T_3098a_row4_col2" class="data row4 col2" >-0.88</td>
#       <td id="T_3098a_row4_col3" class="data row4 col3" >-0.26</td>
#       <td id="T_3098a_row4_col4" class="data row4 col4" >-0.89</td>
#       <td id="T_3098a_row4_col5" class="data row4 col5" >-0.55</td>
#       <td id="T_3098a_row4_col6" class="data row4 col6" >-0.84</td>
#       <td id="T_3098a_row4_col7" class="data row4 col7" >-0.82</td>
#       <td id="T_3098a_row4_col8" class="data row4 col8" >-0.63</td>
#       <td id="T_3098a_row4_col9" class="data row4 col9" >-0.76</td>
#       <td id="T_3098a_row4_col10" class="data row4 col10" >-0.57</td>
#       <td id="T_3098a_row4_col11" class="data row4 col11" >0.21</td>
#       <td id="T_3098a_row4_col12" class="data row4 col12" >-0.81</td>
#       <td id="T_3098a_row4_col13" class="data row4 col13" >16.68</td>
#     </tr>
#     <tr>
#       <th id="T_3098a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_3098a_row5_col0" class="data row5 col0" >-0.38</td>
#       <td id="T_3098a_row5_col1" class="data row5 col1" >-0.48</td>
#       <td id="T_3098a_row5_col2" class="data row5 col2" >-0.21</td>
#       <td id="T_3098a_row5_col3" class="data row5 col3" >-0.26</td>
#       <td id="T_3098a_row5_col4" class="data row5 col4" >-0.17</td>
#       <td id="T_3098a_row5_col5" class="data row5 col5" >-0.10</td>
#       <td id="T_3098a_row5_col6" class="data row5 col6" >0.34</td>
#       <td id="T_3098a_row5_col7" class="data row5 col7" >-0.29</td>
#       <td id="T_3098a_row5_col8" class="data row5 col8" >-0.51</td>
#       <td id="T_3098a_row5_col9" class="data row5 col9" >-0.46</td>
#       <td id="T_3098a_row5_col10" class="data row5 col10" >0.28</td>
#       <td id="T_3098a_row5_col11" class="data row5 col11" >0.39</td>
#       <td id="T_3098a_row5_col12" class="data row5 col12" >-0.19</td>
#       <td id="T_3098a_row5_col13" class="data row5 col13" >20.75</td>
#     </tr>
#     <tr>
#       <th id="T_3098a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_3098a_row6_col0" class="data row6 col0" >-0.01</td>
#       <td id="T_3098a_row6_col1" class="data row6 col1" >0.04</td>
#       <td id="T_3098a_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_3098a_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_3098a_row6_col4" class="data row6 col4" >0.
# ===== PREVIEW: TEST SET AFTER NORM =====
# <style type="text/css">
# </style>
# <table id="T_24431" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24431_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_24431_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_24431_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_24431_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_24431_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_24431_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_24431_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_24431_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_24431_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_24431_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_24431_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_24431_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_24431_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_24431_level0_col13" class="col_heading level0 col13" >MEDV</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24431_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_24431_row0_col0" class="data row0 col0" >102.00</td>
#       <td id="T_24431_row0_col1" class="data row0 col1" >102.00</td>
#       <td id="T_24431_row0_col2" class="data row0 col2" >102.00</td>
#       <td id="T_24431_row0_col3" class="data row0 col3" >102.00</td>
#       <td id="T_24431_row0_col4" class="data row0 col4" >102.00</td>
#       <td id="T_24431_row0_col5" class="data row0 col5" >102.00</td>
#       <td id="T_24431_row0_col6" class="data row0 col6" >102.00</td>
#       <td id="T_24431_row0_col7" class="data row0 col7" >102.00</td>
#       <td id="T_24431_row0_col8" class="data row0 col8" >102.00</td>
#       <td id="T_24431_row0_col9" class="data row0 col9" >102.00</td>
#       <td id="T_24431_row0_col10" class="data row0 col10" >102.00</td>
#       <td id="T_24431_row0_col11" class="data row0 col11" >102.00</td>
#       <td id="T_24431_row0_col12" class="data row0 col12" >102.00</td>
#       <td id="T_24431_row0_col13" class="data row0 col13" >102.00</td>
#     </tr>
#     <tr>
#       <th id="T_24431_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_24431_row1_col0" class="data row1 col0" >-0.07</td>
#       <td id="T_24431_row1_col1" class="data row1 col1" >-0.02</td>
#       <td id="T_24431_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_24431_row1_col3" class="data row1 col3" >0.15</td>
#       <td id="T_24431_row1_col4" class="data row1 col4" >-0.11</td>
#       <td id="T_24431_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_24431_row1_col6" class="data row1 col6" >-0.08</td>
#       <td id="T_24431_row1_col7" class="data row1 col7" >0.13</td>
#       <td id="T_24431_row1_col8" class="data row1 col8" >0.06</td>
#       <td id="T_24431_row1_col9" class="data row1 col9" >0.07</td>
#       <td id="T_24431_row1_col10" class="data row1 col10" >-0.05</td>
#       <td id="T_24431_row1_col11" class="data row1 col11" >0.10</td>
#       <td id="T_24431_row1_col12" class="data row1 col12" >-0.06</td>
#       <td id="T_24431_row1_col13" class="data row1 col13" >23.08</td>
#     </tr>
#     <tr>
#       <th id="T_24431_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_24431_row2_col0" class="data row2 col0" >0.58</td>
#       <td id="T_24431_row2_col1" class="data row2 col1" >0.91</td>
#       <td id="T_24431_row2_col2" class="data row2 col2" >1.04</td>
#       <td id="T_24431_row2_col3" class="data row2 col3" >1.24</td>
#       <td id="T_24431_row2_col4" class="data row2 col4" >0.94</td>
#       <td id="T_24431_row2_col5" class="data row2 col5" >0.95</td>
#       <td id="T_24431_row2_col6" class="data row2 col6" >1.04</td>
#       <td id="T_24431_row2_col7" class="data row2 col7" >1.17</td>
#       <td id="T_24431_row2_col8" class="data row2 col8" >1.01</td>
#       <td id="T_24431_row2_col9" class="data row2 col9" >1.07</td>
#       <td id="T_24431_row2_col10" class="data row2 col10" >0.92</td>
#       <td id="T_24431_row2_col11" class="data row2 col11" >0.84</td>
#       <td id="T_24431_row2_col12" class="data row2 col12" >0.92</td>
#       <td id="T_24431_row2_col13" class="data row2 col13" >9.17</td>
#     </tr>
#     <tr>
#       <th id="T_24431_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T
level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_24431_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_24431_row6_col1" class="data row6 col1" >0.20</td>
#       <td id="T_24431_row6_col2" class="data row6 col2" >1.03</td>
#       <td id="T_24431_row6_col3" class="data row6 col3" >-0.26</td>
#       <td id="T_24431_row6_col4" class="data row6 col4" >0.

# %% [markdown]
# For data to be processed by the model, convert them to float32 dtype

# %%
# A conversion function
convert = lambda a: a.astype(np.float32)

# Convert and inspect
vars = [ ('x_train_norm',x_train_norm), ('y_train',y_train), ('x_test_norm',x_test_norm), ('y_test',y_test) ]
for name,var in vars:
  var = convert(var)
  print(f"{name}: type={type(var)} , shape={var.shape} , dtype={var.dtype}")
# Out:
# x_train_norm: type=<class 'numpy.ndarray'> , shape=(404, 13) , dtype=float32
# y_train: type=<class 'numpy.ndarray'> , shape=(404,) , dtype=float32
# x_test_norm: type=<class 'numpy.ndarray'> , shape=(102, 13) , dtype=float32
# y_test: type=<class 'numpy.ndarray'> , shape=(102,) , dtype=float32

# %% [markdown]
# # 3. Create the network architecture

# %%
def create_model():
  model = keras.models.Sequential()

  # Input layer
  model.add( keras.Input(shape=(x_train_norm.shape[-1],), name='input') )

  # Hidden layers
  model.add( keras.layers.Dense(8, activation='relu', name='hidden1') )   # Use default weight initialization, don't use any regularization
  model.add( keras.layers.BatchNormalization(axis=-1, name='bn1') )
  model.add( keras.layers.Dense(16, activation='relu', name='hidden2') )  # Use default weight initialization, don't use any regularization
  model.add( keras.layers.BatchNormalization(axis=-1, name='bn2') )
  model.add( keras.layers.Dense(8, activation='relu', name='hidden3') )   # Use default weight initialization, don't use any regularization
  model.add( keras.layers.Dropout(0.3) )          # drop rate = 30%

  # Output layer: For a regression problem, use a linear activation function (a.k.a., use no activation function)
  model.add( keras.layers.Dense(1, name='output') )

  # Compile with default values for both optimizer and loss
  model.compile( optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'] )

  return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ hidden1 (Dense)                 │ (None, 8)              │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn1 (BatchNormalization)        │ (None, 8)              │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn2 (BatchNormalization)        │ (None, 16)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden3 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 449 (1.75 KB)
#  Non-trainable params: 48 (192.00 B)

# %% [markdown]
# # 4. Train the model on train set

# %% [markdown]
# According to https://keras.io/guides/serialization_and_saving/:
# - A Keras model consists of multiple components:
#   - The architecture, or configuration, which specifies what layers the model contain, and how they're connected.
#   - A set of weights values (the "state of the model").
#   - An optimizer (defined by compiling the model).
#   - A set of losses and metrics (defined by compiling the model).
# - The Keras API saves all of the above components together in a unified format, marked by the `.keras` extension. This is a zip archive consisting of the following:
#   - A JSON-based configuration file (`config.json`): Records of model, layer, and other trackables' configuration.
#   - A H5-based state file, such as `model.weights.h5` (for the whole model), with directory keys for layers and their weights.
#   - A metadata file in JSON, storing things such as the current Keras version.

# %%
menu = '\n1. Save weights only\n2. Save the full model\nYour choice: '

while True:
  choice = input(menu).strip()
  if choice in ['1', '2']:
    save_weights_only = True if choice=='1' else False
    break
# Out:
# 1. Save weights only
# 2. Save the full model
# Your choice: 2

# %%
# https://keras.io/api/callbacks/model_checkpoint/

if save_weights_only:
  checkpoint_filepath = "bestmodel_epoch{epoch:03d}_valloss{val_loss:.2f}.weights.h5"
else:
  checkpoint_filepath = "bestmodel_epoch{epoch:03d}_valloss{val_loss:.2f}.keras"

model_checkpoint_callback = keras.callbacks.ModelCheckpoint( filepath=checkpoint_filepath,
                                                                save_weights_only=save_weights_only,
                                                                monitor='val_loss',
                                                                mode='min',
                                                                save_best_only=True )

# %% [markdown]
# If you encounter a case where validation loss is lower than train loss, read this article for explanation https://towardsdatascience.com/what-your-validation-loss-is-lower-than-your-training-loss-this-is-why-5e92e0b1747e.

# %%
history = model.fit ( x_train_norm, y_train,
                      validation_split=0.2,
                      batch_size=32, epochs=100, verbose=1,
                      callbacks=[model_checkpoint_callback]
                  )
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 335ms/step - loss: 546.9959 - mean_absolute_error: 21.5548 - val_loss: 636.9248 - val_mean_absolute_error: 23.4957
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 544.8314 - mean_absolute_error: 21.3835 - val_loss: 630.0618 - val_mean_absolute_error: 23.3580
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 506.0030 - mean_absolute_error: 20.8096 - val_loss: 622.1984 - val_mean_absolute_error: 23.2051
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 570.6660 - mean_absolute_error: 21.8435 - val_loss: 612.9852 - val_mean_absolute_error: 23.0273
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 500.8679 - mean_absolute_error: 20.5445 - val_loss: 603.4385 - val_mean_absolute_error: 22.8451
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 483.4459 - mean_absolute_error: 20.2668 - val_loss: 592.4052 - val_mean_absolute_error: 22.6345
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 466.8581 - mean_absolute_error: 20.0079 - val_loss: 580.7960 - val_mean_absolute_error: 22.4126
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 471.5595 - mean_absolute_error: 19.9881 - val_loss: 567.2245 - val_mean_absolute_error: 22.1512
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 476.1509 - mean_absolute_error: 19.9973 - val_loss: 553.7043 - val_mean_absolute_error: 21.8879
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 417.9114 - mean_absolute_error: 18.8425 - val_loss: 537.5035 - val_mean_absolute_error: 21.5738
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 418.8056 - mean_absolute_error: 18.8974 - val_loss: 520.3508 - val_mean_absolute_error: 21.2439
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 403.4038 - mean_absolute_error: 18.6087 - val_loss: 499.2796 - val_mean_absolute_error: 20.8277
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 377.7966 - mean_absolute_error: 17.8353 - val_loss: 474.5854 - val_mean_absolute_error: 20.3147
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 386.2109 - mean_absolute_error: 17.9688 - val_loss: 450.8298 - val_mean_absolute_error: 19.7945
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 368.9084 - mean_absolute_error: 17.5466 - val_loss: 426.5708 - val_mean_absolute_error: 19.2404
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 315.7275 - mean_absolute_error: 16.4436 - val_loss: 402.3490 - val_mean_absolute_error: 18.6683
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 310.5325 - mean_absolute_error: 16.0896 - val_loss: 374.9674 - val_mean_absolute_error: 17.9848
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 298.3827 - mean_absolute_error: 15.6909 - val_loss: 349.8419 - val_mean_absolute_error: 17.3139
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 312.3698 - mean_absolute_error: 15.6774 - val_loss: 322.5918 - val_mean_absolute_error: 16.5444
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 262.9477 - mean_absolute_error: 14.3744 - val_loss: 297.5981 - val_mean_absolute_error: 15.8051
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 271.2054 - mean_absolute_error: 14.4589 - val_loss: 272.9217 - val_mean_absolute_error: 15.0203
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 247.0035 - mean_absolute_error: 13.6053 - val_loss: 251.0191 - val_mean_absolute_error: 14.2638
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 199.7638 - mean_absolute_error: 12.4388 - val_loss: 239.4962 - val_mean_absolute_error: 13.8713
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 203.2633 - mean_absolute_error: 12.2894 - val_loss: 222.9936 - val_mean_absolute_error: 13.2546
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 212.4000 - mean_absolute_error: 12.1977 - val_loss: 205.4400 - val_mean_absolute_error: 12.5513
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 182.2708 - mean_absolute_error: 11.4083 - val_loss: 189.8344 - val_mean_absolute_error: 11.9193
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 170.5490 - mean_absolute_error: 11.0453 - val_loss: 173.6649 - val_mean_absolute_error: 11.1554
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 138.7554 - mean_absolute_error: 9.7812 - val_loss: 163.2978 - val_mean_absolute_error: 10.6629
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 179.7639 - mean_absolute_error: 10.9600 - val_loss: 149.2677 - val_mean_absolute_error: 9.9854
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 154.1722 - mean_absolute_error: 9.7261 - val_loss: 139.4034 - val_mean_absolute_error: 9.5053
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 185.1730 - mean_absolute_error: 10.9196 - val_loss: 129.6000 - val_mean_absolute_error: 9.0222
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 161.0536 - mean_absolute_error: 10.2413 - val_loss: 121.1709 - val_mean_absolute_error: 8.6105
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 140.2373 - mean_absolute_error: 9.2100 - val_loss: 112.2261 - val_mean_absolute_error: 8.1489
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 129.2198 - mean_absolute_error: 8.6999 - val_loss: 103.5611 - val_mean_absolute_error: 7.6770
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 117.7962 - mean_absolute_error: 8.1130 - val_loss: 98.7788 - val_mean_absolute_error: 7.4464
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 102.3735 - mean_absolute_error: 7.8467 - val_loss: 94.3873 - val_mean_absolute_error: 7.2174
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 144.4382 - mean_absolute_error: 9.1675 - val_loss: 89.3565 - val_mean_absolute_error: 6.9436
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 130.7874 - mean_absolute_error: 8.6048 - val_loss: 83.8351 - val_mean_absolute_error: 6.6356
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 110.3369 - mean_absolute_error: 7.8605 - val_loss: 80.3759 - val_mean_absolute_error: 6.4406
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 104.8062 - mean_absolute_error: 7.5615 - val_loss: 76.3873 - val_mean_absolute_error: 6.2125
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 110.3478 - mean_absolute_error: 7.8976 - val_loss: 73.0904 - val_mean_absolute_error: 6.0225
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 98.7666 - mean_absolute_error: 7.5227 - val_loss: 69.9621 - val_mean_absolute_error: 5.8261
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 89.3129 - mean_absolute_error: 6.9433 - val_loss: 66.9878 - val_mean_absolute_error: 5.6545
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 113.2809 - mean_absolute_error: 7.9028 - val_loss: 62.9302 - val_mean_absolute_error: 5.4123
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 113.1269 - mean_absolute_error: 7.9446 - val_loss: 59.6066 - val_mean_absolute_error: 5.2136
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 94.5750 - mean_absolute_error: 7.3211 - val_loss: 56.8766 - val_mean_absolute_error: 5.0292
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 98.6729 - mean_absolute_error: 7.3923 - val_loss: 56.1416 - val_mean_absolute_error: 4.9697
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 105.3755 - mean_absolute_error: 7.8627 - val_loss: 55.8589 - val_mean_absolute_error: 4.9602
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 106.3479 - mean_absolute_error: 7.7017 - val_loss: 55.7118 - val_mean_absolute_error: 4.9663
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 97.7131 - mean_absolute_error: 7.3079 - val_loss: 55.5337 - val_mean_absolute_error: 4.9691
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 99.7347 - mean_absolute_error: 7.3302 - val_loss: 55.1035 - val_mean_absolute_error: 4.9469
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 100.4729 - mean_absolute_error: 7.5137 - val_loss: 53.8665 - val_mean_absolute_error: 4.8740
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 84.5902 - mean_absolute_error: 7.1240 - val_loss: 52.2398 - val_mean_absolute_error: 4.7631
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 114.0456 - mean_absolute_error: 7.6616 - val_loss: 49.9606 - val_mean_absolute_error: 4.6224
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 81.4976 - mean_absolute_error: 6.5106 - val_loss: 48.6918 - val_mean_absolute_error: 4.5362
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 74.5754 - mean_absolute_error: 6.5034 - val_loss: 45.8952 - val_mean_absolute_error: 4.2300
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 97.5798 - mean_absolute_error: 7.5167 - val_loss: 44.4818 - val_mean_absolute_error: 4.0946
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 105.7224 - mean_absolute_error: 7.3301 - val_loss: 44.0660 - val_mean_absolute_error: 4.0562
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 92.5597 - mean_absolute_error: 7.4430 - val_loss: 45.4088 - val_mean_absolute_error: 4.1768
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 103.2723 - mean_absolute_error: 7.6832 - val_loss: 45.2373 - val_mean_absolute_error: 4.1506
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 103.2170 - mean_absolute_error: 7.3500 - val_loss: 45.4460 - val_mean_absolute_error: 4.1718
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 107.4718 - mean_absolute_error: 7.6811 - val_loss: 45.4269 - val_mean_absolute_error: 4.1806
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82.3160 - mean_absolute_error: 6.6231 - val_loss: 46.3508 - val_mean_absolute_error: 4.2789
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 109.4849 - mean_absolute_error: 7.9579 - val_loss: 46.1749 - val_mean_absolute_error: 4.2821
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 87.9879 - mean_absolute_error: 7.0905 - val_loss: 46.6996 - val_mean_absolute_error: 4.3145
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 89.2211 - mean_absolute_error: 7.0230 - val_loss: 46.4484 - val_mean_absolute_error: 4.3088
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 93.0086 - mean_absolute_error: 7.0544 - val_loss: 46.4600 - val_mean_absolute_error: 4.3342
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 82.6668 - mean_absolute_error: 6.9449 - val_loss: 46.1159 - val_mean_absolute_error: 4.3071
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 91.4487 - mean_absolute_error: 6.9882 - val_loss: 46.6444 - val_mean_absolute_error: 4.3348
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 88.1993 - mean_absolute_error: 7.0329 - val_loss: 46.0346 - val_mean_absolute_error: 4.2977
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 93.7639 - mean_absolute_error: 6.8372 - val_loss: 45.5346 - val_mean_absolute_error: 4.2776
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 82.5794 - mean_absolute_error: 7.1150 - val_loss: 46.1282 - val_mean_absolute_error: 4.3037
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 74.3897 - mean_absolute_error: 6.5849 - val_loss: 45.2130 - val_mean_absolute_error: 4.2264
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 97.1140 - mean_absolute_error: 7.4450 - val_loss: 46.2030 - val_mean_absolute_error: 4.3192
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 82.0866 - mean_absolute_error: 6.6992 - val_loss: 45.9753 - val_mean_absolute_error: 4.3631
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 95.3856 - mean_absolute_error: 7.3134 - val_loss: 46.4721 - val_mean_absolute_error: 4.4128
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 75.1563 - mean_absolute_error: 6.6051 - val_loss: 46.5791 - val_mean_absolute_error: 4.3897
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 101.2771 - mean_absolute_error: 7.5457 - val_loss: 45.6442 - val_mean_absolute_error: 4.3045
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 79.1756 - mean_absolute_error: 6.6867 - val_loss: 46.4671 - val_mean_absolute_error: 4.3359
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 90.3466 - mean_absolute_error: 6.9910 - val_loss: 46.9913 - val_mean_absolute_error: 4.3735
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 86.0909 - mean_absolute_error: 7.0909 - val_loss: 46.5218 - val_mean_absolute_error: 4.3237
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 98.0841 - mean_absolute_error: 7.2458 - val_loss: 45.9368 - val_mean_absolute_error: 4.2860
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 96.8977 - mean_absolute_error: 7.0713 - val_loss: 45.2234 - val_mean_absolute_error: 4.2805
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 101.8136 - mean_absolute_error: 7.7892 - val_loss: 44.8243 - val_mean_absolute_error: 4.2701
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 83.7860 - mean_absolute_error: 7.0020 - val_loss: 46.8090 - val_mean_absolute_error: 4.4140
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 81.1034 - mean_absolute_error: 6.7364 - val_loss: 46.5038 - val_mean_absolute_error: 4.3660
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 106.8152 - mean_absolute_error: 7.6789 - val_loss: 45.0371 - val_mean_absolute_error: 4.2460
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 89.0168 - mean_absolute_error: 7.0821 - val_loss: 44.2602 - val_mean_absolute_error: 4.1958
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 88.2396 - mean_absolute_error: 6.9892 - val_loss: 44.2466 - val_mean_absolute_error: 4.2031
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 106.8818 - mean_absolute_error: 7.6686 - val_loss: 44.2562 - val_mean_absolute_error: 4.2255
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 87.4402 - mean_absolute_error: 6.9090 - val_loss: 44.1612 - val_mean_absolute_error: 4.2265
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 84.0549 - mean_absolute_error: 7.0033 - val_loss: 42.9379 - val_mean_absolute_error: 4.1417
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 83.9568 - mean_absolute_error: 7.0492 - val_loss: 41.6492 - val_mean_absolute_error: 4.0793
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 82.6086 - mean_absolute_error: 6.9184 - val_loss: 42.7240 - val_mean_absolute_error: 4.1787
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 79.8580 - mean_absolute_error: 6.7100 - val_loss: 43.8615 - val_mean_absolute_error: 4.2653
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 79.9420 - mean_absolute_error: 6.8927 - val_loss: 45.3155 - val_mean_absolute_error: 4.3748
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 89.7255 - mean_absolute_error: 7.2000 - val_loss: 44.6210 - val_mean_absolute_error: 4.3308
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 94.3375 - mean_absolute_error: 7.3241 - val_loss: 43.7122 - val_mean_absolute_error: 4.2710
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 95.0221 - mean_absolute_error: 7.3288 - val_loss: 43.8842 - val_mean_absolute_error: 4.2985
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 90.9102 - mean_absolute_error: 6.9720 - val_loss: 43.9919 - val_mean_absolute_error: 4.2966

# %%
# Inspect the saved files (sorted by modification date, newest first)
# !ls -lt
# Out:
# total 3124
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch093_valloss41.65.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch092_valloss42.94.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch058_valloss44.07.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch057_valloss44.48.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch056_valloss45.90.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch055_valloss48.69.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch054_valloss49.96.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch053_valloss52.24.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch052_valloss53.87.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch051_valloss55.10.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch050_valloss55.53.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch049_valloss55.71.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch048_valloss55.86.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch047_valloss56.14.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch046_valloss56.88.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch045_valloss59.61.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch044_valloss62.93.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch043_valloss66.99.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch042_valloss69.96.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:59 bestmodel_epoch041_valloss73.09.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch040_valloss76.39.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch039_valloss80.38.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch038_valloss83.84.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch037_valloss89.36.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch036_valloss94.39.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch035_valloss98.78.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch034_valloss103.56.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch033_valloss112.23.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch032_valloss121.17.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch031_valloss129.60.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch030_valloss139.40.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch029_valloss149.27.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch028_valloss163.30.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch027_valloss173.66.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch026_valloss189.83.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch025_valloss205.44.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch024_valloss222.99.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch023_valloss239.50.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch022_valloss251.02.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch021_valloss272.92.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch020_valloss297.60.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch019_valloss322.59.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch018_valloss349.84.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch017_valloss374.97.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch016_valloss402.35.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch015_valloss426.57.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch014_valloss450.83.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch013_valloss474.59.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch012_valloss499.28.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch011_valloss520.35.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch010_valloss537.50.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch009_valloss553.70.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch008_valloss567.22.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch007_valloss580.80.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch006_valloss592.41.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch005_valloss603.44.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch004_valloss612.99.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch003_valloss622.20.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch002_valloss630.06.keras
# -rw-r--r-- 1 root root 49860 Aug 19 15:58 bestmodel_epoch001_valloss636.92.keras
# drwxr-xr-x 1 root root  4096 Aug 15 13:35 sample_data

# %%
# Check the keys in 'history'
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
# Summarize history for MSE loss
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss (MSE)')
plt.ylabel('Mean Squared Error')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Summarize history for MAE
plt.figure(figsize=(15,5))
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Metric (MAE)')
plt.ylabel('Mean Absolute Error')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# # 5. Evaluate the model on test set

# %% [markdown]
# Evaluate the model from the last epoch:

# %%
results = model.evaluate(x_test_norm, y_test, batch_size=50, return_dict=True)
print( results )
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.7190 - mean_absolute_error: 4.5142
# {'loss': 36.32396697998047, 'mean_absolute_error': 4.621874809265137}

# %% [markdown]
# Load the best model (which may not be the same as the model from the last epoch):

# %%
if save_weights_only:
  # Get the name of the newest .weights.h5 file
  files = [x for x in os.listdir('./') if x.endswith(".weights.h5")]
  newest = max(files , key=os.path.getctime)

  # Load weights of the best model
  best_model = create_model()     # Load the network architecture
  best_model.load_weights(newest) # Load weights
  print(f"Successfully loaded '{newest}' to 'best_model'")
else:
  # Get the name of the newest .keras file
  files = [x for x in os.listdir('./') if x.endswith(".keras")]
  newest = max(files , key=os.path.getctime)

  # Load the best model
  best_model = keras.models.load_model(newest)
  print(f"Successfully loaded '{newest}' to 'best_model'")
# Out:
# Successfully loaded 'bestmodel_epoch093_valloss41.65.keras' to 'best_model'

# %% [markdown]
# Evaluate the model from the best epoch:

# %%
# If the model isn't compiled, there will be Error in .evaluate()
results = best_model.evaluate(x_test_norm, y_test, batch_size=50)
print( f"{best_model.metrics_names} = {results}" )
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.8066 - mean_absolute_error: 4.2583
# ['loss', 'compile_metrics'] = [34.5972785949707, 4.378048419952393]

# %% [markdown]
# # 6. Inference

# %%
# Predict one row of data
i = 0
y_pred0 = model.predict( x_test_norm[i].reshape(1,-1) )   # Reshape x_test[i] from (n_feature,) to (1, n_feature)
print(f'{y_pred0.shape=}')

# Inspect the result
print(f"x_test[{i}] = {x_test[i]}")
print(f"x_test_norm[{i}] = {x_test_norm[i]}")
print(f"y_test[{i}] = {y_test[i]}")
print(f"y_pred = {y_pred0}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# y_pred0.shape=(1, 1)
# x_test[0] = [ 18.0846   0.      18.1      0.       0.679    6.434  100.       1.8347
#   24.     666.      20.2     27.25    29.05  ]
# x_test_norm[0] = [ 1.55369355 -0.48361547  1.0283258  -0.25683275  1.03838067  0.23545815
#   1.11048828 -0.93976936  1.67588577  1.5652875   0.78447637 -3.48459553
#   2.25092074]
# y_test[0] = 7.2
# y_pred = [[4.0761347]]

# %%
# Predict many rows of data at once
i,j = 2,21
y_preds = model.predict( x_test_norm[i:j] )
print(f'{y_preds.shape=}')

# Inspect the results
results = boston_dataframe(x_test[i:j], y_test)         # Create the test dataframe of 14 columns (13 features + 1 output)
results.rename(columns={'MEDV':'y_true'}, inplace=True) # Rename the last column from 'MEDV' to 'y_true'
results['y_pred'] = pd.Series(y_preds.squeeze())        # Append the prediction results as the rightmost column
results['Abs. Error'] = (results['y_true'] - results['y_pred']).abs()  # Compute Absolute Error betweeon 'y_true' and 'y_pred'
                                                                       # Append Absolute Error values as a new column

results.style.format(precision=2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# y_preds.shape=(19, 1)
# <style type="text/css">
# </style>
# <table id="T_e3211" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3211_level0_col0" class="col_heading level0 col0" >CRIM</th>
#       <th id="T_e3211_level0_col1" class="col_heading level0 col1" >ZN</th>
#       <th id="T_e3211_level0_col2" class="col_heading level0 col2" >INDUS</th>
#       <th id="T_e3211_level0_col3" class="col_heading level0 col3" >CHAS</th>
#       <th id="T_e3211_level0_col4" class="col_heading level0 col4" >NOX</th>
#       <th id="T_e3211_level0_col5" class="col_heading level0 col5" >RM</th>
#       <th id="T_e3211_level0_col6" class="col_heading level0 col6" >AGE</th>
#       <th id="T_e3211_level0_col7" class="col_heading level0 col7" >DIS</th>
#       <th id="T_e3211_level0_col8" class="col_heading level0 col8" >RAD</th>
#       <th id="T_e3211_level0_col9" class="col_heading level0 col9" >TAX</th>
#       <th id="T_e3211_level0_col10" class="col_heading level0 col10" >PTRATIO</th>
#       <th id="T_e3211_level0_col11" class="col_heading level0 col11" >B</th>
#       <th id="T_e3211_level0_col12" class="col_heading level0 col12" >LSTAT</th>
#       <th id="T_e3211_level0_col13" class="col_heading level0 col13" >y_true</th>
#       <th id="T_e3211_level0_col14" class="col_heading level0 col14" >y_pred</th>
#       <th id="T_e3211_level0_col15" class="col_heading level0 col15" >Abs. Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e