# %% [markdown]
# Predict the next number using a deep RNN. All codes are the same as ex1, except for Section 2.

# %% [markdown]
# # 1. Prepare the environment

# %%
# List all NVIDIA GPUs as available in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA L4 (UUID: GPU-b0c42bac-2c6d-02f5-7477-dbb748850634)

# %%
import sys
print( f"Python {sys.version}\n" )

import numpy as np
print( f"NumPy {np.__version__}\n" )

import matplotlib.pyplot as plt
# %matplotlib inline

# https://keras.io/getting_started/
# The backend must be configured before importing Keras, and the backend cannot be changed after the package has been imported.
import os
os.environ["KERAS_BACKEND"] = "torch"  # "jax", "tensorflow"

import keras
print(f"Keras {keras.__version__}")
print(f"|- Keras backend = {keras.backend.backend()}")
print(f"|- Keras backend image data format = {keras.backend.image_data_format()}\n")

import torch
print( f"PyTorch {torch.__version__}" )

# Get all available accelerators such as CUDA, MPS, MTIA, or XPU
num_accelerators = torch.accelerator.device_count()

if (num_accelerators <= 0):
    print("|- No hardware accelerators found. Using CPU only.")
else:
    print(f"|- PyTorch detected {num_accelerators} hardware accelerator(s)")
    print(f"|- PyTorch detected '{torch.accelerator.current_accelerator().type.upper()}' as the current accelerator")

    # Check cuda availability
    if torch.cuda.is_available():
        num_gpus = torch.cuda.device_count()
        print(f"|- PyTorch detected {num_gpus} CUDA GPU(s):")
    for i in range(num_gpus):
        print(f"   |- CUDA GPU {i}: {torch.cuda.get_device_name(i)}")
# Out:
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
#
# NumPy 2.0.2
#
# Keras 3.10.0
# |- Keras backend = torch
# |- Keras backend image data format = channels_last
#
# PyTorch 2.8.0+cu126
# |- PyTorch detected 1 hardware accelerator(s)
# |- PyTorch detected 'CUDA' as the current accelerator
# |- PyTorch detected 1 CUDA GPU(s):
#    |- CUDA GPU 0: NVIDIA L4

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed

# https://keras.io/examples/keras_recipes/reproducibility_recipes/
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
#keras.utils.set_random_seed(1234)

# %% [markdown]
# # 2. Create the deep RNN model

# %%
my_rnn = keras.models.Sequential()
my_rnn.add( keras.layers.Input(shape=(None,1)) )

# batch_size=None, time_steps=None, input_dim=1
## RNN layer 1
my_rnn.add( keras.layers.SimpleRNN( units=20, return_sequences=True ) )
## RNN layer 2
my_rnn.add( keras.layers.SimpleRNN( units=20, return_sequences=True ) )
## RNN layer 3
my_rnn.add( keras.layers.SimpleRNN( units=10 ) )

# Use the default linear activation
my_rnn.add( keras.layers.Dense(1) )

my_rnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, None, 20)       │           440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, None, 20)       │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,581 (6.18 KB)
#  Trainable params: 1,581 (6.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 3. Create train/val/test sets
#
# - Generate a 1D time series from `start_val` to `stop_val` with step 2:

# %%
start_val , stop_val = -4000 , 2000

# Create raw data
series = np.arange(start_val, stop_val+1, 2)
n_data = series.shape[0]

# Preview
print(f"{type(series)=} , {series.shape=} , {series}")
# Out:
# type(series)=<class 'numpy.ndarray'> , series.shape=(3001,) , [-4000 -3998 -3996 ...  1996  1998  2000]

# %% [markdown]
# - <u>Split the data from oldest to newest</u>: first 80% for training, next 10% for validation, last 10% for testing.
# - Compute the training statistics (mean and SD) <u>using only the training portion</u>.
# - Normalize the entire 1D sequence (z-score) using the training statistics.

# %%
# Split ratios
n_train = int(n_data * 0.8)         # 80% train
n_test = int(n_data * 0.1)          # 10% test
n_val = n_data - n_train - n_test   # 10% validation

# Compute training's mean and SD
train_mean = np.mean(series[:n_train])
train_std = np.std(series[:n_train])

# Normalize entire series using training stats
series_norm = (series - train_mean) / train_std
print(f"{type(series_norm)=} , {series_norm.shape=} , {series_norm}")
# Out:
# type(series_norm)=<class 'numpy.ndarray'> , series_norm.shape=(3001,) , [-1.73132927 -1.72988589 -1.72844252 ...  2.59591137  2.59735475
#   2.59879812]

# %% [markdown]
# - Split the normalized 1D sequence (`series_norm`) into input sequences `X_norm` (each containing `n_input_timesteps`=5 consecutive values) and targets `Y_norm` (the next value following each sequence). The unnormalized versions (`X` and `Y`) are kept only for reference.

# %%
# Sliding window parameters
n_input_timesteps = 5  # number of timesteps for input sequence

# Generate sliding windows
X, Y = [], []
X_norm, Y_norm = [], []
for i in range(len(series_norm) - n_input_timesteps):
    X.append(series[i:i+n_input_timesteps])
    Y.append(series[i+n_input_timesteps])

    X_norm.append(series_norm[i:i+n_input_timesteps])
    Y_norm.append(series_norm[i+n_input_timesteps])

X = np.array(X)
Y = np.array(Y)
X_norm = np.array(X_norm)
Y_norm = np.array(Y_norm)

# Preview
print(f"{type(X)=} , {X.shape=} , {X}")
print(f"{type(Y)=} , {Y.shape=} , {Y}\n")
print(f"{type(X_norm)=} , {X_norm.shape=} , {X_norm}")
print(f"{type(Y_norm)=} , {Y_norm.shape=} , {Y_norm}")
# Out:
# type(X)=<class 'numpy.ndarray'> , X.shape=(2996, 5) , [[-4000 -3998 -3996 -3994 -3992]
#  [-3998 -3996 -3994 -3992 -3990]
#  [-3996 -3994 -3992 -3990 -3988]
#  ...
#  [ 1986  1988  1990  1992  1994]
#  [ 1988  1990  1992  1994  1996]
#  [ 1990  1992  1994  1996  1998]]
# type(Y)=<class 'numpy.ndarray'> , Y.shape=(2996,) , [-3990 -3988 -3986 ...  1996  1998  2000]
#
# type(X_norm)=<class 'numpy.ndarray'> , X_norm.shape=(2996, 5) , [[-1.73132927 -1.72988589 -1.72844252 -1.72699914 -1.72555577]
#  [-1.72988589 -1.72844252 -1.72699914 -1.72555577 -1.72411239]
#  [-1.72844252 -1.72699914 -1.72555577 -1.72411239 -1.72266902]
#  ...
#  [ 2.58869449  2.59013787  2.59158125  2.59302462  2.594468  ]
#  [ 2.59013787  2.59158125  2.59302462  2.594468    2.59591137]
#  [ 2.59158125  2.59302462  2.594468    2.59591137  2.59735475]]
# type(Y_norm)=<class 'numpy.ndarray'> , Y_norm.shape=(2996,) , [-1.72411239 -1.72266902 -1.72122564 ...  2.59591137  2.59735475
#   2.59879812]

# %% [markdown]
# - Divide `X_norm` and `Y_norm` into training, validation, and test sets. The unnormalized versions are kept only for reference.
# - Reshape `X_norm` into `(batch_size, time_steps, input_dim)` as required by the SimpleRNN layer

# %%
# Split indices
train_end = n_train - n_input_timesteps
val_end = train_end + n_val

# Split into train/val/test
x_train = X[:train_end].reshape(-1, n_input_timesteps, 1)
y_train = Y[:train_end]
x_train_norm = X_norm[:train_end].reshape(-1, n_input_timesteps, 1)
y_train_norm = Y_norm[:train_end]

x_val = X[train_end:val_end].reshape(-1, n_input_timesteps, 1)
y_val = Y[train_end:val_end]
x_val_norm = X_norm[train_end:val_end].reshape(-1, n_input_timesteps, 1)
y_val_norm = Y_norm[train_end:val_end]

x_test = X[val_end:].reshape(-1, n_input_timesteps, 1)
y_test = Y[val_end:]
x_test_norm = X_norm[val_end:].reshape(-1, n_input_timesteps, 1)
y_test_norm = Y_norm[val_end:]

# Preview shapes
print(f"x_train shape: {x_train.shape}, y_train_norm shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val_norm shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test_norm shape: {y_test.shape}")
print(f"x_train_norm shape: {x_train_norm.shape}, y_train_norm shape: {y_train_norm.shape}")
print(f"x_val_norm shape: {x_val_norm.shape}, y_val_norm shape: {y_val_norm.shape}")
print(f"x_test_norm shape: {x_test_norm.shape}, y_test_norm shape: {y_test_norm.shape}")

# Preview first sample
print("\nFirst x_train sample:", x_train[0].ravel())
print("First y_train sample:", y_train[0])
print("First x_train_norm sample:", x_train_norm[0].ravel())
print("First y_train_norm sample:", y_train_norm[0])
# Out:
# x_train shape: (2395, 5, 1), y_train_norm shape: (2395,)
# x_val shape: (301, 5, 1), y_val_norm shape: (301,)
# x_test shape: (300, 5, 1), y_test_norm shape: (300,)
# x_train_norm shape: (2395, 5, 1), y_train_norm shape: (2395,)
# x_val_norm shape: (301, 5, 1), y_val_norm shape: (301,)
# x_test_norm shape: (300, 5, 1), y_test_norm shape: (300,)
#
# First x_train sample: [-4000 -3998 -3996 -3994 -3992]
# First y_train sample: -3990
# First x_train_norm sample: [-1.73132927 -1.72988589 -1.72844252 -1.72699914 -1.72555577]
# First y_train_norm sample: -1.7241123910300602

# %% [markdown]
# # 4. Compile and train the model

# %%
@keras.saving.register_keras_serializable(package="Custom", name="mae_denorm")
def mae_denorm(y_true, y_pred):
    # y_true and y_pred are normalized
    y_true_denorm = (y_true * train_std) + train_mean
    y_pred_denorm = (y_pred * train_std) + train_mean
    return torch.mean(torch.abs(y_true_denorm - y_pred_denorm))

# %%
adam = keras.optimizers.Adam(learning_rate=0.001)

# For regression, the loss can be used as the evaluation metric as well
my_rnn.compile( loss="mse", optimizer=adam, metrics=['mae',mae_denorm] )

# %%
checkpoint_filepath = "RNN_ex2_bestmodel_epoch{epoch:03d}.keras"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint( filepath=checkpoint_filepath,
                                                              save_weights_only=False,
                                                              monitor='val_loss',
                                                              mode='min',
                                                              save_best_only=True)

# %%
hist = my_rnn.fit ( x_train_norm, y_train_norm,
                    validation_data=(x_val_norm,y_val_norm),
                    batch_size=64, epochs=300,
                    callbacks=[model_checkpoint_callback] )
# Out:
# Epoch 1/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.8692 - mae: 0.7321 - mae_denorm: 1418.9493 - val_loss: 0.7529 - val_mae: 0.8593 - val_mae_denorm: 1205.3109
# Epoch 2/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0870 - mae: 0.2489 - mae_denorm: 1490.6727 - val_loss: 0.4694 - val_mae: 0.6750 - val_mae_denorm: 949.6802
# Epoch 3/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0346 - mae: 0.1534 - mae_denorm: 1546.3291 - val_loss: 0.3159 - val_mae: 0.5509 - val_mae_denorm: 777.0632
# Epoch 4/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0128 - mae: 0.0841 - mae_denorm: 1522.3125 - val_loss: 0.2138 - val_mae: 0.4500 - val_mae_denorm: 636.6669
# Epoch 5/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0066 - mae: 0.0621 - mae_denorm: 1543.2854 - val_loss: 0.1680 - val_mae: 0.3972 - val_mae_denorm: 562.9177
# Epoch 6/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0045 - mae: 0.0534 - mae_denorm: 1568.4427 - val_loss: 0.1308 - val_mae: 0.3482 - val_mae_denorm: 494.6779
# Epoch 7/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0032 - mae: 0.0440 - mae_denorm: 1570.1218 - val_loss: 0.1114 - val_mae: 0.3203 - val_mae_denorm: 455.5684
# Epoch 8/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0025 - mae: 0.0383 - mae_denorm: 1562.5176 - val_loss: 0.0960 - val_mae: 0.2964 - val_mae_denorm: 422.0147
# Epoch 9/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - mae: 0.0308 - mae_denorm: 1560.7925 - val_loss: 0.0801 - val_mae: 0.2692 - val_mae_denorm: 384.0433
# Epoch 10/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - mae: 0.0275 - mae_denorm: 1581.3179 - val_loss: 0.0732 - val_mae: 0.2573 - val_mae_denorm: 367.0854
# Epoch 11/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.5324e-04 - mae: 0.0226 - mae_denorm: 1571.8625 - val_loss: 0.0631 - val_mae: 0.2376 - val_mae_denorm: 339.5505
# Epoch 12/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4874e-04 - mae: 0.0215 - mae_denorm: 1562.6913 - val_loss: 0.0552 - val_mae: 0.2211 - val_mae_denorm: 316.4579
# Epoch 13/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.7373e-04 - mae: 0.0190 - mae_denorm: 1582.2423 - val_loss: 0.0522 - val_mae: 0.2153 - val_mae_denorm: 308.1240
# Epoch 14/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.6730e-04 - mae: 0.0179 - mae_denorm: 1563.8698 - val_loss: 0.0447 - val_mae: 0.1976 - val_mae_denorm: 283.3836
# Epoch 15/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8429e-04 - mae: 0.0168 - mae_denorm: 1558.2660 - val_loss: 0.0428 - val_mae: 0.1937 - val_mae_denorm: 277.6858
# Epoch 16/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3648e-04 - mae: 0.0162 - mae_denorm: 1583.3167 - val_loss: 0.0414 - val_mae: 0.1907 - val_mae_denorm: 273.3806
# Epoch 17/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1172e-04 - mae: 0.0158 - mae_denorm: 1593.3634 - val_loss: 0.0377 - val_mae: 0.1812 - val_mae_denorm: 259.9444
# Epoch 18/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1329e-04 - mae: 0.0140 - mae_denorm: 1577.6708 - val_loss: 0.0332 - val_mae: 0.1687 - val_mae_denorm: 242.5432
# Epoch 19/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9745e-04 - mae: 0.0137 - mae_denorm: 1545.2095 - val_loss: 0.0331 - val_mae: 0.1692 - val_mae_denorm: 243.0474
# Epoch 20/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.6302e-04 - mae: 0.0131 - mae_denorm: 1582.3918 - val_loss: 0.0310 - val_mae: 0.1632 - val_mae_denorm: 234.6667
# Epoch 21/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.4915e-04 - mae: 0.0129 - mae_denorm: 1563.9650 - val_loss: 0.0282 - val_mae: 0.1547 - val_mae_denorm: 222.8113
# Epoch 22/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3887e-04 - mae: 0.0125 - mae_denorm: 1580.8451 - val_loss: 0.0284 - val_mae: 0.1560 - val_mae_denorm: 224.3961
# Epoch 23/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0610e-04 - mae: 0.0115 - mae_denorm: 1570.4709 - val_loss: 0.0265 - val_mae: 0.1504 - val_mae_denorm: 216.4869
# Epoch 24/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9504e-04 - mae: 0.0113 - mae_denorm: 1572.3170 - val_loss: 0.0264 - val_mae: 0.1504 - val_mae_denorm: 216.3991
# Epoch 25/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9752e-04 - mae: 0.0112 - mae_denorm: 1576.4834 - val_loss: 0.0239 - val_mae: 0.1420 - val_mae_denorm: 204.7643
# Epoch 26/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5915e-04 - mae: 0.0102 - mae_denorm: 1588.5049 - val_loss: 0.0237 - val_mae: 0.1416 - val_mae_denorm: 203.9800
# Epoch 27/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5137e-04 - mae: 0.0099 - mae_denorm: 1591.8225 - val_loss: 0.0214 - val_mae: 0.1335 - val_mae_denorm: 192.7921
# Epoch 28/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6334e-04 - mae: 0.0102 - mae_denorm: 1594.4543 - val_loss: 0.0220 - val_mae: 0.1363 - val_mae_denorm: 196.5397
# Epoch 29/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2428e-04 - mae: 0.0089 - mae_denorm: 1560.8169 - val_loss: 0.0185 - val_mae: 0.1230 - val_mae_denorm: 178.3495
# Epoch 30/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2140e-04 - mae: 0.0086 - mae_denorm: 1549.4729 - val_loss: 0.0202 - val_mae: 0.1303 - val_mae_denorm: 188.1130
# Epoch 31/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0242e-04 - mae: 0.0081 - mae_denorm: 1551.1210 - val_loss: 0.0199 - val_mae: 0.1294 - val_mae_denorm: 186.7632
# Epoch 32/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0531e-04 - mae: 0.0081 - mae_denorm: 1571.1257 - val_loss: 0.0187 - val_mae: 0.1250 - val_mae_denorm: 180.5678
# Epoch 33/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0756e-04 - mae: 0.0080 - mae_denorm: 1556.8878 - val_loss: 0.0177 - val_mae: 0.1212 - val_mae_denorm: 175.3900
# Epoch 34/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.3612e-05 - mae: 0.0073 - mae_denorm: 1573.0096 - val_loss: 0.0178 - val_mae: 0.1222 - val_mae_denorm: 176.5664
# Epoch 35/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.8178e-05 - mae: 0.0069 - mae_denorm: 1559.2778 - val_loss: 0.0154 - val_mae: 0.1119 - val_mae_denorm: 162.7500
# Epoch 36/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.9554e-05 - mae: 0.0069 - mae_denorm: 1548.3546 - val_loss: 0.0153 - val_mae: 0.1119 - val_mae_denorm: 162.5352
# Epoch 37/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.2568e-05 - mae: 0.0066 - mae_denorm: 1599.5834 - val_loss: 0.0160 - val_mae: 0.1154 - val_mae_denorm: 167.1717
# Epoch 38/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2660e-05 - mae: 0.0060 - mae_denorm: 1556.1547 - val_loss: 0.0146 - val_mae: 0.1092 - val_mae_denorm: 158.8000
# Epoch 39/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.8693e-05 - mae: 0.0062 - mae_denorm: 1550.5713 - val_loss: 0.0133 - val_mae: 0.1031 - val_mae_denorm: 150.6597
# Epoch 40/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0188e-05 - mae: 0.0059 - mae_denorm: 1552.0879 - val_loss: 0.0137 - val_mae: 0.1058 - val_mae_denorm: 154.0422
# Epoch 41/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1925e-05 - mae: 0.0056 - mae_denorm: 1573.1067 - val_loss: 0.0129 - val_mae: 0.1021 - val_mae_denorm: 149.0837
# Epoch 42/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.9487e-05 - mae: 0.0055 - mae_denorm: 1601.6898 - val_loss: 0.0133 - val_mae: 0.1044 - val_mae_denorm: 151.9281
# Epoch 43/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5105e-05 - mae: 0.0052 - mae_denorm: 1570.4832 - val_loss: 0.0130 - val_mae: 0.1030 - val_mae_denorm: 150.0364
# Epoch 44/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1078e-05 - mae: 0.0048 - mae_denorm: 1564.4464 - val_loss: 0.0114 - val_mae: 0.0950 - val_mae_denorm: 139.6037
# Epoch 45/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1522e-05 - mae: 0.0048 - mae_denorm: 1587.4805 - val_loss: 0.0124 - val_mae: 0.1004 - val_mae_denorm: 146.3252
# Epoch 46/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4030e-05 - mae: 0.0044 - mae_denorm: 1576.0417 - val_loss: 0.0113 - val_mae: 0.0952 - val_mae_denorm: 139.5527
# Epoch 47/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2967e-05 - mae: 0.0043 - mae_denorm: 1591.2423 - val_loss: 0.0111 - val_mae: 0.0943 - val_mae_denorm: 138.2665
# Epoch 48/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6681e-05 - mae: 0.0045 - mae_denorm: 1581.7761 - val_loss: 0.0106 - val_mae: 0.0917 - val_mae_denorm: 134.7594
# Epoch 49/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1341e-05 - mae: 0.0042 - mae_denorm: 1583.2966 - val_loss: 0.0104 - val_mae: 0.0909 - val_mae_denorm: 133.6244
# Epoch 50/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9825e-05 - mae: 0.0041 - mae_denorm: 1579.4766 - val_loss: 0.0097 - val_mae: 0.0875 - val_mae_denorm: 129.2854
# Epoch 51/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9109e-05 - mae: 0.0040 - mae_denorm: 1591.7797 - val_loss: 0.0105 - val_mae: 0.0921 - val_mae_denorm: 134.9047
# Epoch 52/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.6086e-05 - mae: 0.0036 - mae_denorm: 1570.4512 - val_loss: 0.0100 - val_mae: 0.0898 - val_mae_denorm: 131.9473
# Epoch 53/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.7301e-05 - mae: 0.0038 - mae_denorm: 1582.0022 - val_loss: 0.0088 - val_mae: 0.0826 - val_mae_denorm: 122.9469
# Epoch 54/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1232e-05 - mae: 0.0041 - mae_denorm: 1575.2777 - val_loss: 0.0091 - val_mae: 0.0850 - val_mae_denorm: 125.6970
# Epoch 55/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3768e-05 - mae: 0.0035 - mae_denorm: 1572.4189 - val_loss: 0.0086 - val_mae: 0.0818 - val_mae_denorm: 121.6178
# Epoch 56/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8856e-05 - mae: 0.0032 - mae_denorm: 1587.6039 - val_loss: 0.0090 - val_mae: 0.0847 - val_mae_denorm: 125.0074
# Epoch 57/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9387e-05 - mae: 0.0032 - mae_denorm: 1569.9257 - val_loss: 0.0080 - val_mae: 0.0788 - val_mae_denorm: 117.6970
# Epoch 58/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2351e-05 - mae: 0.0036 - mae_denorm: 1550.4122 - val_loss: 0.0081 - val_mae: 0.0794 - val_mae_denorm: 118.3970
# Epoch 59/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6814e-05 - mae: 0.0030 - mae_denorm: 1590.2769 - val_loss: 0.0075 - val_mae: 0.0762 - val_mae_denorm: 114.3047
# Epoch 60/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6796e-05 - mae: 0.0029 - mae_denorm: 1572.9392 - val_loss: 0.0078 - val_mae: 0.0778 - val_mae_denorm: 116.1206
# Epoch 61/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3551e-05 - mae: 0.0026 - mae_denorm: 1559.4916 - val_loss: 0.0077 - val_mae: 0.0778 - val_mae_denorm: 116.0249
# Epoch 62/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6252e-05 - mae: 0.0029 - mae_denorm: 1564.8986 - val_loss: 0.0074 - val_mae: 0.0760 - val_mae_denorm: 113.8051
# Epoch 63/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4678e-05 - mae: 0.0028 - mae_denorm: 1594.8942 - val_loss: 0.0072 - val_mae: 0.0750 - val_mae_denorm: 112.3485
# Epoch 64/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2787e-05 - mae: 0.0025 - mae_denorm: 1588.0276 - val_loss: 0.0069 - val_mae: 0.0728 - val_mae_denorm: 109.7867
# Epoch 65/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1783e-05 - mae: 0.0025 - mae_denorm: 1562.9525 - val_loss: 0.0067 - val_mae: 0.0718 - val_mae_denorm: 108.4565
# Epoch 66/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0047e-05 - mae: 0.0022 - mae_denorm: 1547.5255 - val_loss: 0.0063 - val_mae: 0.0688 - val_mae_denorm: 104.8096
# Epoch 67/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1608e-05 - mae: 0.0026 - mae_denorm: 1572.9957 - val_loss: 0.0069 - val_mae: 0.0732 - val_mae_denorm: 109.8303
# Epoch 68/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3863e-05 - mae: 0.0029 - mae_denorm: 1576.6587 - val_loss: 0.0064 - val_mae: 0.0703 - val_mae_denorm: 106.3013
# Epoch 69/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.8124e-06 - mae: 0.0019 - mae_denorm: 1583.5243 - val_loss: 0.0061 - val_mae: 0.0683 - val_mae_denorm: 103.9423
# Epoch 70/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.7163e-06 - mae: 0.0020 - mae_denorm: 1591.7722 - val_loss: 0.0058 - val_mae: 0.0661 - val_mae_denorm: 101.3193
# Epoch 71/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6301e-06 - mae: 0.0019 - mae_denorm: 1563.6307 - val_loss: 0.0061 - val_mae: 0.0685 - val_mae_denorm: 103.9803
# Epoch 72/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.3792e-06 - mae: 0.0019 - mae_denorm: 1592.0115 - val_loss: 0.0054 - val_mae: 0.0632 - val_mae_denorm: 97.9144
# Epoch 73/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.5328e-06 - mae: 0.0018 - mae_denorm: 1557.8042 - val_loss: 0.0057 - val_mae: 0.0653 - val_mae_denorm: 100.1286
# Epoch 74/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0014e-06 - mae: 0.0017 - mae_denorm: 1591.6843 - val_loss: 0.0052 - val_mae: 0.0622 - val_mae_denorm: 96.6167
# Epoch 75/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2125e-06 - mae: 0.0021 - mae_denorm: 1567.5581 - val_loss: 0.0055 - val_mae: 0.0642 - val_mae_denorm: 98.6554
# Epoch 76/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8412e-06 - mae: 0.0019 - mae_denorm: 1585.4471 - val_loss: 0.0053 - val_mae: 0.0630 - val_mae_denorm: 97.2626
# Epoch 77/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.4568e-06 - mae: 0.0018 - mae_denorm: 1584.7869 - val_loss: 0.0052 - val_mae: 0.0624 - val_mae_denorm: 96.5163
# Epoch 78/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.3955e-06 - mae: 0.0016 - mae_denorm: 1595.7579 - val_loss: 0.0051 - val_mae: 0.0613 - val_mae_denorm: 95.1980
# Epoch 79/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.1688e-06 - mae: 0.0017 - mae_denorm: 1577.5002 - val_loss: 0.0049 - val_mae: 0.0601 - val_mae_denorm: 93.7751
# Epoch 80/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.5724e-06 - mae: 0.0019 - mae_denorm: 1550.1481 - val_loss: 0.0048 - val_mae: 0.0595 - val_mae_denorm: 93.0450
# Epoch 81/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8658e-06 - mae: 0.0020 - mae_denorm: 1581.0746 - val_loss: 0.0049 - val_mae: 0.0604 - val_mae_denorm: 93.9004
# Epoch 82/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.5587e-06 - mae: 0.0017 - mae_denorm: 1600.9554 - val_loss: 0.0047 - val_mae: 0.0586 - val_mae_denorm: 91.8715
# Epoch 83/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3230e-06 - mae: 0.0018 - mae_denorm: 1576.7722 - val_loss: 0.0048 - val_mae: 0.0601 - val_mae_denorm: 93.4011
# Epoch 84/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.7919e-06 - mae: 0.0020 - mae_denorm: 1571.7542 - val_loss: 0.0045 - val_mae: 0.0575 - val_mae_denorm: 90.5698
# Epoch 85/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.8790e-06 - mae: 0.0018 - mae_denorm: 1571.0376 - val_loss: 0.0044 - val_mae: 0.0565 - val_mae_denorm: 89.4339
# Epoch 86/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3597e-06 - mae: 0.0017 - mae_denorm: 1579.9537 - val_loss: 0.0047 - val_mae: 0.0591 - val_mae_denorm: 92.1164
# Epoch 87/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.7603e-06 - mae: 0.0016 - mae_denorm: 1569.9023 - val_loss: 0.0046 - val_mae: 0.0587 - val_mae_denorm: 91.5456
# Epoch 88/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.3318e-06 - mae: 0.0020 - mae_denorm: 1578.4780 - val_loss: 0.0045 - val_mae: 0.0575 - val_mae_denorm: 90.2602
# Epoch 89/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.6325e-06 - mae: 0.0016 - mae_denorm: 1570.1794 - val_loss: 0.0041 - val_mae: 0.0545 - val_mae_denorm: 87.0619
# Epoch 90/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3327e-06 - mae: 0.0016 - mae_denorm: 1562.0229 - val_loss: 0.0044 - val_mae: 0.0571 - val_mae_denorm: 89.6048
# Epoch 91/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1924e-06 - mae: 0.0015 - mae_denorm: 1567.0149 - val_loss: 0.0039 - val_mae: 0.0530 - val_mae_denorm: 85.3253
# Epoch 92/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.0757e-06 - mae: 0.0017 - mae_denorm: 1566.0231 - val_loss: 0.0040 - val_mae: 0.0542 - val_mae_denorm: 86.4118
# Epoch 93/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0003e-06 - mae: 0.0015 - mae_denorm: 1559.1178 - val_loss: 0.0039 - val_mae: 0.0531 - val_mae_denorm: 85.2551
# Epoch 94/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7422e-06 - mae: 0.0015 - mae_denorm: 1569.3289 - val_loss: 0.0039 - val_mae: 0.0536 - val_mae_denorm: 85.6417
# Epoch 95/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.2649e-06 - mae: 0.0022 - mae_denorm: 1567.1663 - val_loss: 0.0036 - val_mae: 0.0502 - val_mae_denorm: 82.2490
# Epoch 96/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2488e-05 - mae: 0.0029 - mae_denorm: 1584.2695 - val_loss: 0.0039 - val_mae: 0.0534 - val_mae_denorm: 85.3420
# Epoch 97/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0684e-06 - mae: 0.0015 - mae_denorm: 1569.9899 - val_loss: 0.0037 - val_mae: 0.0518 - val_mae_denorm: 83.6846
# Epoch 98/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2965e-06 - mae: 0.0016 - mae_denorm: 1582.3273 - val_loss: 0.0035 - val_mae: 0.0492 - val_mae_denorm: 81.1046
# Epoch 99/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.4277e-06 - mae: 0.0021 - mae_denorm: 1592.1683 - val_loss: 0.0040 - val_mae: 0.0548 - val_mae_denorm: 86.6205
# Epoch 100/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.3930e-06 - mae: 0.0020 - mae_denorm: 1580.5735 - val_loss: 0.0039 - val_mae: 0.0540 - val_mae_denorm: 85.7216
# Epoch 101/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0716e-05 - mae: 0.0025 - mae_denorm: 1586.1508 - val_loss: 0.0038 - val_mae: 0.0529 - val_mae_denorm: 84.4956
# Epoch 102/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9471e-06 - mae: 0.0019 - mae_denorm: 1579.6562 - val_loss: 0.0039 - val_mae: 0.0543 - val_mae_denorm: 85.8871
# Epoch 103/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.1531e-06 - mae: 0.0018 - mae_denorm: 1574.4822 - val_loss: 0.0032 - val_mae: 0.0471 - val_mae_denorm: 78.7507
# Epoch 104/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.3267e-06 - mae: 0.0022 - mae_denorm: 1589.0966 - val_loss: 0.0034 - val_mae: 0.0489 - val_mae_denorm: 80.3768
# Epoch 105/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2296e-05 - mae: 0.0028 - mae_denorm: 1574.6060 - val_loss: 0.0032 - val_mae: 0.0472 - val_mae_denorm: 78.6441
# Epoch 106/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0153e-05 - mae: 0.0026 - mae_denorm: 1557.6901 - val_loss: 0.0030 - val_mae: 0.0452 - val_mae_denorm: 76.6959
# Epoch 107/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8170e-05 - mae: 0.0033 - mae_denorm: 1559.5604 - val_loss: 0.0031 - val_mae: 0.0459 - val_mae_denorm: 77.2621
# Epoch 108/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.0448e-06 - mae: 0.0021 - mae_denorm: 1571.5924 - val_loss: 0.0036 - val_mae: 0.0511 - val_mae_denorm: 82.3108
# Epoch 109/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.6836e-06 - mae: 0.0024 - mae_denorm: 1580.3799 - val_loss: 0.0033 - val_mae: 0.0484 - val_mae_denorm: 79.5915
# Epoch 110/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8013e-06 - mae: 0.0017 - mae_denorm: 1574.6351 - val_loss: 0.0032 - val_mae: 0.0471 - val_mae_denorm: 78.2376
# Epoch 111/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4193e-06 - mae: 0.0017 - mae_denorm: 1590.2010 - val_loss: 0.0032 - val_mae: 0.0472 - val_mae_denorm: 78.3383
# Epoch 112/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8472e-06 - mae: 0.0017 - mae_denorm: 1578.1802 - val_loss: 0.0033 - val_mae: 0.0484 - val_mae_denorm: 79.3111
# Epoch 113/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4868e-06 - mae: 0.0015 - mae_denorm: 1571.8521 - val_loss: 0.0030 - val_mae: 0.0460 - val_mae_denorm: 77.0198
# Epoch 114/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.0955e-06 - mae: 0.0021 - mae_denorm: 1568.1415 - val_loss: 0.0030 - val_mae: 0.0454 - val_mae_denorm: 76.4056
# Epoch 115/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.5381e-06 - mae: 0.0022 - mae_denorm: 1534.8191 - val_loss: 0.0032 - val_mae: 0.0477 - val_mae_denorm: 78.4826
# Epoch 116/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3846e-06 - mae: 0.0016 - mae_denorm: 1576.5588 - val_loss: 0.0031 - val_mae: 0.0475 - val_mae_denorm: 78.2351
# Epoch 117/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0865e-06 - mae: 0.0019 - mae_denorm: 1587.0946 - val_loss: 0.0030 - val_mae: 0.0464 - val_mae_denorm: 77.1692
# Epoch 118/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1644e-06 - mae: 0.0014 - mae_denorm: 1554.5702 - val_loss: 0.0032 - val_mae: 0.0482 - val_mae_denorm: 78.8762
# Epoch 119/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3237e-06 - mae: 0.0019 - mae_denorm: 1561.5477 - val_loss: 0.0031 - val_mae: 0.0476 - val_mae_denorm: 78.2297
# Epoch 120/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8600e-06 - mae: 0.0023 - mae_denorm: 1598.9437 - val_loss: 0.0030 - val_mae: 0.0468 - val_mae_denorm: 77.3507
# Epoch 121/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0153e-05 - mae: 0.0026 - mae_denorm: 1586.2800 - val_loss: 0.0029 - val_mae: 0.0452 - val_mae_denorm: 75.8583
# Epoch 122/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.8886e-06 - mae: 0.0024 - mae_denorm: 1570.5413 - val_loss: 0.0028 - val_mae: 0.0440 - val_mae_denorm: 74.7420
# Epoch 123/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.2489e-06 - mae: 0.0021 - mae_denorm: 1587.2576 - val_loss: 0.0033 - val_mae: 0.0495 - val_mae_denorm: 79.8075
# Epoch 124/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.7892e-05 - mae: 0.0063 - mae_denorm: 1580.9272 - val_loss: 0.0027 - val_mae: 0.0434 - val_mae_denorm: 74.0553
# Epoch 125/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.6557e-06 - mae: 0.0025 - mae_denorm: 1597.4364 - val_loss: 0.0024 - val_mae: 0.0392 - val_mae_denorm: 70.3929
# Epoch 126/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8365e-05 - mae: 0.0035 - mae_denorm: 1566.4738 - val_loss: 0.0030 - val_mae: 0.0463 - val_mae_denorm: 76.5939
# Epoch 127/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1990e-05 - mae: 0.0060 - mae_denorm: 1557.2653 - val_loss: 0.0027 - val_mae: 0.0433 - val_mae_denorm: 73.9129
# Epoch 128/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.3416e-05 - mae: 0.0047 - mae_denorm: 1560.6744 - val_loss: 0.0028 - val_mae: 0.0442 - val_mae_denorm: 74.6458
# Epoch 129/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.8202e-06 - mae: 0.0013 - mae_denorm: 1579.7705 - val_loss: 0.0027 - val_mae: 0.0435 - val_mae_denorm: 73.9122
# Epoch 130/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7179e-06 - mae: 0.0015 - mae_denorm: 1556.5524 - val_loss: 0.0025 - val_mae: 0.0403 - val_mae_denorm: 71.0822
# Epoch 131/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4248e-06 - mae: 0.0017 - mae_denorm: 1567.5858 - val_loss: 0.0028 - val_mae: 0.0450 - val_mae_denorm: 75.1926
# Epoch 132/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2207e-05 - mae: 0.0036 - mae_denorm: 1592.6692 - val_loss: 0.0032 - val_mae: 0.0493 - val_mae_denorm: 79.3822
# Epoch 133/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0441e-05 - mae: 0.0046 - mae_denorm: 1569.2028 - val_loss: 0.0026 - val_mae: 0.0422 - val_mae_denorm: 72.6663
# Epoch 134/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1305e-05 - mae: 0.0027 - mae_denorm: 1567.3615 - val_loss: 0.0022 - val_mae: 0.0368 - val_mae_denorm: 68.0766
# Epoch 135/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8394e-05 - mae: 0.0049 - mae_denorm: 1549.3196 - val_loss: 0.0017 - val_mae: 0.0314 - val_mae_denorm: 62.7777
# Epoch 136/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7055e-05 - mae: 0.0033 - mae_denorm: 1578.7240 - val_loss: 0.0027 - val_mae: 0.0432 - val_mae_denorm: 73.4316
# Epoch 137/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.0498e-06 - mae: 0.0021 - mae_denorm: 1542.4021 - val_loss: 0.0026 - val_mae: 0.0427 - val_mae_denorm: 72.9971
# Epoch 138/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8651e-06 - mae: 0.0022 - mae_denorm: 1563.2549 - val_loss: 0.0025 - val_mae: 0.0411 - val_mae_denorm: 71.5229
# Epoch 139/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.8746e-06 - mae: 0.0019 - mae_denorm: 1581.4987 - val_loss: 0.0027 - val_mae: 0.0440 - val_mae_denorm: 74.0775
# Epoch 140/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1181e-06 - mae: 0.0016 - mae_denorm: 1584.8969 - val_loss: 0.0022 - val_mae: 0.0376 - val_mae_denorm: 68.4192
# Epoch 141/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.9290e-05 - mae: 0.0060 - mae_denorm: 1573.4647 - val_loss: 0.0039 - val_mae: 0.0564 - val_mae_denorm: 86.7150
# Epoch 142/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0444e-04 - mae: 0.0082 - mae_denorm: 1588.3804 - val_loss: 0.0029 - val_mae: 0.0460 - val_mae_denorm: 76.1459
# Epoch 143/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7148e-05 - mae: 0.0032 - mae_denorm: 1559.6423 - val_loss: 0.0025 - val_mae: 0.0419 - val_mae_denorm: 72.2069
# Epoch 144/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.8974e-06 - mae: 0.0018 - mae_denorm: 1574.1675 - val_loss: 0.0026 - val_mae: 0.0430 - val_mae_denorm: 73.1342
# Epoch 145/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1228e-06 - mae: 0.0014 - mae_denorm: 1583.8917 - val_loss: 0.0027 - val_mae: 0.0434 - val_mae_denorm: 73.4946
# Epoch 146/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0284e-06 - mae: 0.0016 - mae_denorm: 1560.3680 - val_loss: 0.0025 - val_mae: 0.0419 - val_mae_denorm: 72.0335
# Epoch 147/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3982e-06 - mae: 0.0012 - mae_denorm: 1601.5286 - val_loss: 0.0023 - val_mae: 0.0386 - val_mae_denorm: 69.1223
# Epoch 148/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5245e-05 - mae: 0.0030 - mae_denorm: 1582.6382 - val_loss: 0.0029 - val_mae: 0.0459 - val_mae_denorm: 75.8914
# Epoch 149/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3303e-05 - mae: 0.0039 - mae_denorm: 1553.8928 - val_loss: 0.0021 - val_mae: 0.0353 - val_mae_denorm: 66.5838
# Epoch 150/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7317e-05 - mae: 0.0051 - mae_denorm: 1583.7128 - val_loss: 0.0026 - val_mae: 0.0424 - val_mae_denorm: 72.6566
# Epoch 151/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.6277e-05 - mae: 0.0077 - mae_denorm: 1568.4427 - val_loss: 0.0030 - val_mae: 0.0467 - val_mae_denorm: 76.8012
# Epoch 152/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.5547e-05 - mae: 0.0059 - mae_denorm: 1612.2976 - val_loss: 0.0026 - val_mae: 0.0422 - val_mae_denorm: 72.6338
# Epoch 153/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0887e-05 - mae: 0.0026 - mae_denorm: 1576.0779 - val_loss: 0.0023 - val_mae: 0.0380 - val_mae_denorm: 68.9298
# Epoch 154/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6297e-06 - mae: 0.0017 - mae_denorm: 1588.4899 - val_loss: 0.0024 - val_mae: 0.0400 - val_mae_denorm: 70.4899
# Epoch 155/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7592e-06 - mae: 0.0015 - mae_denorm: 1578.2114 - val_loss: 0.0022 - val_mae: 0.0371 - val_mae_denorm: 68.0280
# Epoch 156/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5098e-06 - mae: 0.0017 - mae_denorm: 1573.8219 - val_loss: 0.0025 - val_mae: 0.0417 - val_mae_denorm: 71.8163
# Epoch 157/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0140e-06 - mae: 0.0015 - mae_denorm: 1591.7992 - val_loss: 0.0027 - val_mae: 0.0437 - val_mae_denorm: 73.5992
# Epoch 158/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.6139e-06 - mae: 0.0026 - mae_denorm: 1589.1642 - val_loss: 0.0025 - val_mae: 0.0414 - val_mae_denorm: 71.5341
# Epoch 159/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5996e-05 - mae: 0.0033 - mae_denorm: 1567.1746 - val_loss: 0.0022 - val_mae: 0.0381 - val_mae_denorm: 68.5806
# Epoch 160/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7757e-06 - mae: 0.0013 - mae_denorm: 1534.0560 - val_loss: 0.0026 - val_mae: 0.0430 - val_mae_denorm: 72.8569
# Epoch 161/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0180e-06 - mae: 0.0015 - mae_denorm: 1577.1544 - val_loss: 0.0024 - val_mae: 0.0409 - val_mae_denorm: 70.8658
# Epoch 162/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9496e-05 - mae: 0.0037 - mae_denorm: 1545.0591 - val_loss: 0.0023 - val_mae: 0.0397 - val_mae_denorm: 69.8831
# Epoch 163/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8948e-06 - mae: 0.0020 - mae_denorm: 1570.8906 - val_loss: 0.0022 - val_mae: 0.0381 - val_mae_denorm: 68.4077
# Epoch 164/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0072e-06 - mae: 0.0019 - mae_denorm: 1565.5267 - val_loss: 0.0024 - val_mae: 0.0414 - val_mae_denorm: 71.1340
# Epoch 165/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7316e-05 - mae: 0.0034 - mae_denorm: 1556.3196 - val_loss: 0.0019 - val_mae: 0.0336 - val_mae_denorm: 64.7271
# Epoch 166/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5588e-05 - mae: 0.0031 - mae_denorm: 1555.3274 - val_loss: 0.0026 - val_mae: 0.0430 - val_mae_denorm: 72.7088
# Epoch 167/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8936e-05 - mae: 0.0052 - mae_denorm: 1549.8646 - val_loss: 0.0022 - val_mae: 0.0376 - val_mae_denorm: 68.3841
# Epoch 168/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9519e-05 - mae: 0.0046 - mae_denorm: 1594.8074 - val_loss: 0.0022 - val_mae: 0.0370 - val_mae_denorm: 67.7990
# Epoch 169/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1963e-05 - mae: 0.0028 - mae_denorm: 1560.6921 - val_loss: 0.0020 - val_mae: 0.0351 - val_mae_denorm: 66.0598
# Epoch 170/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7292e-05 - mae: 0.0033 - mae_denorm: 1582.2140 - val_loss: 0.0025 - val_mae: 0.0422 - val_mae_denorm: 72.0111
# Epoch 171/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1381e-05 - mae: 0.0079 - mae_denorm: 1585.1479 - val_loss: 0.0041 - val_mae: 0.0580 - val_mae_denorm: 88.5914
# Epoch 172/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3155e-04 - mae: 0.0094 - mae_denorm: 1570.6333 - val_loss: 0.0036 - val_mae: 0.0530 - val_mae_denorm: 83.3122
# Epoch 173/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4438e-05 - mae: 0.0048 - mae_denorm: 1602.5477 - val_loss: 0.0030 - val_mae: 0.0462 - val_mae_denorm: 76.4958
# Epoch 174/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1699e-06 - mae: 0.0024 - mae_denorm: 1575.8282 - val_loss: 0.0025 - val_mae: 0.0415 - val_mae_denorm: 71.9807
# Epoch 175/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8695e-06 - mae: 0.0010 - mae_denorm: 1569.0704 - val_loss: 0.0023 - val_mae: 0.0389 - val_mae_denorm: 69.6353
# Epoch 176/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.1494e-06 - mae: 0.0022 - mae_denorm: 1577.3950 - val_loss: 0.0025 - val_mae: 0.0411 - val_mae_denorm: 71.4624
# Epoch 177/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9853e-06 - mae: 0.0020 - mae_denorm: 1539.0586 - val_loss: 0.0024 - val_mae: 0.0403 - val_mae_denorm: 70.7689
# Epoch 178/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9686e-06 - mae: 0.0021 - mae_denorm: 1557.1896 - val_loss: 0.0024 - val_mae: 0.0405 - val_mae_denorm: 70.9728
# Epoch 179/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.1689e-06 - mae: 0.0021 - mae_denorm: 1558.9869 - val_loss: 0.0034 - val_mae: 0.0519 - val_mae_denorm: 81.7817
# Epoch 180/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8477e-05 - mae: 0.0043 - mae_denorm: 1581.6195 - val_loss: 0.0021 - val_mae: 0.0355 - val_mae_denorm: 66.6782
# Epoch 181/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.8013e-06 - mae: 0.0023 - mae_denorm: 1570.8949 - val_loss: 0.0025 - val_mae: 0.0409 - val_mae_denorm: 71.2466
# Epoch 182/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7324e-05 - mae: 0.0032 - mae_denorm: 1569.2397 - val_loss: 0.0024 - val_mae: 0.0398 - val_mae_denorm: 70.1401
# Epoch 183/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5892e-06 - mae: 0.0013 - mae_denorm: 1585.3969 - val_loss: 0.0023 - val_mae: 0.0393 - val_mae_denorm: 69.5564
# Epoch 184/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7907e-06 - mae: 0.0013 - mae_denorm: 1571.7067 - val_loss: 0.0022 - val_mae: 0.0383 - val_mae_denorm: 68.6542
# Epoch 185/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4782e-06 - mae: 8.8047e-04 - mae_denorm: 1559.0349 - val_loss: 0.0027 - val_mae: 0.0448 - val_mae_denorm: 74.4108
# Epoch 186/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4910e-05 - mae: 0.0032 - mae_denorm: 1572.5381 - val_loss: 0.0020 - val_mae: 0.0356 - val_mae_denorm: 66.3833
# Epoch 187/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9731e-06 - mae: 0.0021 - mae_denorm: 1569.1193 - val_loss: 0.0027 - val_mae: 0.0439 - val_mae_denorm: 73.7131
# Epoch 188/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.3035e-06 - mae: 0.0019 - mae_denorm: 1563.3970 - val_loss: 0.0023 - val_mae: 0.0396 - val_mae_denorm: 69.8843
# Epoch 189/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2349e-05 - mae: 0.0028 - mae_denorm: 1560.5424 - val_loss: 0.0028 - val_mae: 0.0451 - val_mae_denorm: 74.7645
# Epoch 190/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3271e-05 - mae: 0.0028 - mae_denorm: 1577.0796 - val_loss: 0.0027 - val_mae: 0.0445 - val_mae_denorm: 74.2595
# Epoch 191/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7383e-05 - mae: 0.0033 - mae_denorm: 1576.0842 - val_loss: 0.0024 - val_mae: 0.0411 - val_mae_denorm: 71.0210
# Epoch 192/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3089e-05 - mae: 0.0040 - mae_denorm: 1585.1407 - val_loss: 0.0026 - val_mae: 0.0432 - val_mae_denorm: 72.9166
# Epoch 193/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3647e-05 - mae: 0.0030 - mae_denorm: 1559.1898 - val_loss: 0.0023 - val_mae: 0.0390 - val_mae_denorm: 69.1042
# Epoch 194/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5023e-05 - mae: 0.0030 - mae_denorm: 1566.1929 - val_loss: 0.0024 - val_mae: 0.0408 - val_mae_denorm: 70.7064
# Epoch 195/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2099e-06 - mae: 0.0014 - mae_denorm: 1573.1881 - val_loss: 0.0023 - val_mae: 0.0394 - val_mae_denorm: 69.3927
# Epoch 196/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2455e-06 - mae: 0.0014 - mae_denorm: 1580.7164 - val_loss: 0.0021 - val_mae: 0.0377 - val_mae_denorm: 67.9233
# Epoch 197/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3194e-06 - mae: 0.0013 - mae_denorm: 1573.8933 - val_loss: 0.0024 - val_mae: 0.0412 - val_mae_denorm: 70.8484
# Epoch 198/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8524e-06 - mae: 0.0015 - mae_denorm: 1559.9318 - val_loss: 0.0020 - val_mae: 0.0358 - val_mae_denorm: 66.2055
# Epoch 199/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.9630e-06 - mae: 0.0021 - mae_denorm: 1587.7627 - val_loss: 0.0020 - val_mae: 0.0356 - val_mae_denorm: 66.1192
# Epoch 200/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2993e-05 - mae: 0.0030 - mae_denorm: 1568.9514 - val_loss: 0.0021 - val_mae: 0.0373 - val_mae_denorm: 67.3748
# Epoch 201/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0714e-04 - mae: 0.0066 - mae_denorm: 1528.4001 - val_loss: 0.0013 - val_mae: 0.0282 - val_mae_denorm: 57.4982
# Epoch 202/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.5043e-04 - mae: 0.0213 - mae_denorm: 1574.8715 - val_loss: 0.0044 - val_mae: 0.0576 - val_mae_denorm: 90.0011
# Epoch 203/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.7275e-05 - mae: 0.0064 - mae_denorm: 1554.4567 - val_loss: 0.0039 - val_mae: 0.0535 - val_mae_denorm: 85.5738
# Epoch 204/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3359e-05 - mae: 0.0028 - mae_denorm: 1568.5026 - val_loss: 0.0034 - val_mae: 0.0483 - val_mae_denorm: 80.2243
# Epoch 205/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3297e-06 - mae: 0.0012 - mae_denorm: 1551.2903 - val_loss: 0.0032 - val_mae: 0.0469 - val_mae_denorm: 78.7726
# Epoch 206/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7291e-06 - mae: 9.9651e-04 - mae_denorm: 1555.6613 - val_loss: 0.0030 - val_mae: 0.0443 - val_mae_denorm: 76.2228
# Epoch 207/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2247e-06 - mae: 0.0012 - mae_denorm: 1551.0093 - val_loss: 0.0029 - val_mae: 0.0432 - val_mae_denorm: 75.1363
# Epoch 208/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2052e-06 - mae: 0.0011 - mae_denorm: 1585.9664 - val_loss: 0.0030 - val_mae: 0.0451 - val_mae_denorm: 76.7209
# Epoch 209/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3162e-07 - mae: 7.2836e-04 - mae_denorm: 1557.2183 - val_loss: 0.0030 - val_mae: 0.0446 - val_mae_denorm: 76.1762
# Epoch 210/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.4471e-07 - mae: 7.1424e-04 - mae_denorm: 1547.1246 - val_loss: 0.0030 - val_mae: 0.0454 - val_mae_denorm: 76.7470
# Epoch 211/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2749e-06 - mae: 0.0012 - mae_denorm: 1579.4827 - val_loss: 0.0030 - val_mae: 0.0448 - val_mae_denorm: 76.1426
# Epoch 212/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4626e-06 - mae: 9.4224e-04 - mae_denorm: 1600.3666 - val_loss: 0.0026 - val_mae: 0.0411 - val_mae_denorm: 72.7855
# Epoch 213/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3330e-06 - mae: 0.0012 - mae_denorm: 1578.9446 - val_loss: 0.0030 - val_mae: 0.0450 - val_mae_denorm: 76.1724
# Epoch 214/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5658e-06 - mae: 9.6656e-04 - mae_denorm: 1580.2889 - val_loss: 0.0029 - val_mae: 0.0443 - val_mae_denorm: 75.5065
# Epoch 215/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2746e-06 - mae: 0.0012 - mae_denorm: 1564.0752 - val_loss: 0.0029 - val_mae: 0.0441 - val_mae_denorm: 75.1909
# Epoch 216/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8210e-07 - mae: 6.7520e-04 - mae_denorm: 1566.2125 - val_loss: 0.0027 - val_mae: 0.0420 - val_mae_denorm: 73.1793
# Epoch 217/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.2976e-07 - mae: 7.4250e-04 - mae_denorm: 1571.6091 - val_loss: 0.0027 - val_mae: 0.0422 - val_mae_denorm: 73.3437
# Epoch 218/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4302e-07 - mae: 6.9371e-04 - mae_denorm: 1589.0901 - val_loss: 0.0027 - val_mae: 0.0432 - val_mae_denorm: 74.1431
# Epoch 219/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3925e-06 - mae: 9.2943e-04 - mae_denorm: 1566.4358 - val_loss: 0.0024 - val_mae: 0.0390 - val_mae_denorm: 70.3478
# Epoch 220/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5490e-06 - mae: 9.7268e-04 - mae_denorm: 1580.9795 - val_loss: 0.0024 - val_mae: 0.0391 - val_mae_denorm: 70.4819
# Epoch 221/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9024e-06 - mae: 0.0011 - mae_denorm: 1538.8486 - val_loss: 0.0025 - val_mae: 0.0406 - val_mae_denorm: 71.5690
# Epoch 222/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3614e-06 - mae: 8.7786e-04 - mae_denorm: 1569.8973 - val_loss: 0.0025 - val_mae: 0.0408 - val_mae_denorm: 71.7775
# Epoch 223/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4072e-06 - mae: 9.3916e-04 - mae_denorm: 1574.9557 - val_loss: 0.0025 - val_mae: 0.0410 - val_mae_denorm: 71.8241
# Epoch 224/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.4153e-07 - mae: 6.1542e-04 - mae_denorm: 1583.5459 - val_loss: 0.0024 - val_mae: 0.0396 - val_mae_denorm: 70.5659
# Epoch 225/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0157e-06 - mae: 7.7482e-04 - mae_denorm: 1550.1731 - val_loss: 0.0024 - val_mae: 0.0391 - val_mae_denorm: 70.0943
# Epoch 226/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9348e-06 - mae: 0.0019 - mae_denorm: 1571.4701 - val_loss: 0.0024 - val_mae: 0.0404 - val_mae_denorm: 71.0793
# Epoch 227/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6503e-06 - mae: 0.0015 - mae_denorm: 1584.6229 - val_loss: 0.0025 - val_mae: 0.0415 - val_mae_denorm: 71.9897
# Epoch 228/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.0691e-06 - mae: 0.0019 - mae_denorm: 1569.2606 - val_loss: 0.0024 - val_mae: 0.0402 - val_mae_denorm: 70.8113
# Epoch 229/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9907e-06 - mae: 0.0011 - mae_denorm: 1571.2567 - val_loss: 0.0019 - val_mae: 0.0327 - val_mae_denorm: 64.4846
# Epoch 230/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.2480e-06 - mae: 0.0021 - mae_denorm: 1562.9197 - val_loss: 0.0021 - val_mae: 0.0362 - val_mae_denorm: 67.3751
# Epoch 231/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1838e-06 - mae: 0.0025 - mae_denorm: 1570.8617 - val_loss: 0.0016 - val_mae: 0.0300 - val_mae_denorm: 61.6849
# Epoch 232/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1961e-05 - mae: 0.0028 - mae_denorm: 1563.1188 - val_loss: 0.0022 - val_mae: 0.0376 - val_mae_denorm: 68.4918
# Epoch 233/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3654e-05 - mae: 0.0047 - mae_denorm: 1585.8257 - val_loss: 0.0021 - val_mae: 0.0354 - val_mae_denorm: 67.0316
# Epoch 234/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5350e-06 - mae: 0.0017 - mae_denorm: 1586.1969 - val_loss: 0.0025 - val_mae: 0.0406 - val_mae_denorm: 71.3088
# Epoch 235/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6936e-06 - mae: 9.8663e-04 - mae_denorm: 1584.8195 - val_loss: 0.0024 - val_mae: 0.0396 - val_mae_denorm: 70.3518
# Epoch 236/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9840e-06 - mae: 0.0014 - mae_denorm: 1578.3328 - val_loss: 0.0024 - val_mae: 0.0399 - val_mae_denorm: 70.5063
# Epoch 237/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8586e-06 - mae: 0.0013 - mae_denorm: 1551.4468 - val_loss: 0.0022 - val_mae: 0.0377 - val_mae_denorm: 68.6483
# Epoch 238/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.4250e-06 - mae: 0.0020 - mae_denorm: 1596.6646 - val_loss: 0.0021 - val_mae: 0.0356 - val_mae_denorm: 66.9094
# Epoch 239/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.9730e-06 - mae: 0.0017 - mae_denorm: 1565.7338 - val_loss: 0.0019 - val_mae: 0.0327 - val_mae_denorm: 64.4694
# Epoch 240/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9626e-05 - mae: 0.0049 - mae_denorm: 1563.6995 - val_loss: 0.0015 - val_mae: 0.0289 - val_mae_denorm: 60.3061
# Epoch 241/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8178e-04 - mae: 0.0133 - mae_denorm: 1558.7123 - val_loss: 0.0022 - val_mae: 0.0360 - val_mae_denorm: 68.2737
# Epoch 242/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7469e-05 - mae: 0.0048 - mae_denorm: 1574.1410 - val_loss: 0.0029 - val_mae: 0.0437 - val_mae_denorm: 75.2637
# Epoch 243/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.3315e-06 - mae: 0.0021 - mae_denorm: 1573.4917 - val_loss: 0.0029 - val_mae: 0.0445 - val_mae_denorm: 75.8051
# Epoch 244/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2098e-06 - mae: 8.2803e-04 - mae_denorm: 1589.1538 - val_loss: 0.0028 - val_mae: 0.0434 - val_mae_denorm: 74.7077
# Epoch 245/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0346e-06 - mae: 0.0015 - mae_denorm: 1590.6587 - val_loss: 0.0023 - val_mae: 0.0369 - val_mae_denorm: 68.9540
# Epoch 246/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0797e-06 - mae: 0.0016 - mae_denorm: 1538.0682 - val_loss: 0.0026 - val_mae: 0.0407 - val_mae_denorm: 72.0669
# Epoch 247/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4306e-06 - mae: 0.0015 - mae_denorm: 1584.3138 - val_loss: 0.0030 - val_mae: 0.0456 - val_mae_denorm: 76.3620
# Epoch 248/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.1025e-06 - mae: 0.0017 - mae_denorm: 1560.0342 - val_loss: 0.0025 - val_mae: 0.0403 - val_mae_denorm: 71.5379
# Epoch 249/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7472e-06 - mae: 0.0010 - mae_denorm: 1572.0909 - val_loss: 0.0025 - val_mae: 0.0407 - val_mae_denorm: 71.8649
# Epoch 250/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1229e-06 - mae: 0.0014 - mae_denorm: 1583.7650 - val_loss: 0.0027 - val_mae: 0.0431 - val_mae_denorm: 73.8219
# Epoch 251/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.5285e-06 - mae: 0.0015 - mae_denorm: 1548.5205 - val_loss: 0.0022 - val_mae: 0.0360 - val_mae_denorm: 67.7850
# Epoch 252/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3129e-06 - mae: 0.0024 - mae_denorm: 1576.9633 - val_loss: 0.0026 - val_mae: 0.0417 - val_mae_denorm: 72.4632
# Epoch 253/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.1019e-05 - mae: 0.0057 - mae_denorm: 1557.9608 - val_loss: 0.0027 - val_mae: 0.0427 - val_mae_denorm: 73.2884
# Epoch 254/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4690e-05 - mae: 0.0049 - mae_denorm: 1567.4827 - val_loss: 0.0026 - val_mae: 0.0418 - val_mae_denorm: 72.8350
# Epoch 255/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.5686e-06 - mae: 0.0015 - mae_denorm: 1577.0371 - val_loss: 0.0027 - val_mae: 0.0429 - val_mae_denorm: 73.7957
# Epoch 256/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7505e-06 - mae: 9.9469e-04 - mae_denorm: 1563.2112 - val_loss: 0.0025 - val_mae: 0.0402 - val_mae_denorm: 71.3081
# Epoch 257/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8083e-06 - mae: 9.8914e-04 - mae_denorm: 1575.9083 - val_loss: 0.0024 - val_mae: 0.0396 - val_mae_denorm: 70.7815
# Epoch 258/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4354e-05 - mae: 0.0030 - mae_denorm: 1559.2480 - val_loss: 0.0023 - val_mae: 0.0380 - val_mae_denorm: 69.5911
# Epoch 259/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9757e-05 - mae: 0.0051 - mae_denorm: 1579.9733 - val_loss: 0.0029 - val_mae: 0.0450 - val_mae_denorm: 75.8979
# Epoch 260/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8245e-06 - mae: 0.0016 - mae_denorm: 1564.6219 - val_loss: 0.0023 - val_mae: 0.0379 - val_mae_denorm: 69.7042
# Epoch 261/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2678e-06 - mae: 0.0011 - mae_denorm: 1577.7438 - val_loss: 0.0027 - val_mae: 0.0423 - val_mae_denorm: 73.3524
# Epoch 262/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.1318e-06 - mae: 0.0022 - mae_denorm: 1557.7476 - val_loss: 0.0029 - val_mae: 0.0452 - val_mae_denorm: 75.9254
# Epoch 263/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5528e-05 - mae: 0.0038 - mae_denorm: 1581.6746 - val_loss: 0.0028 - val_mae: 0.0434 - val_mae_denorm: 74.5281
# Epoch 264/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2643e-05 - mae: 0.0053 - mae_denorm: 1567.8582 - val_loss: 0.0030 - val_mae: 0.0461 - val_mae_denorm: 76.8167
# Epoch 265/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1166e-05 - mae: 0.0075 - mae_denorm: 1560.9877 - val_loss: 0.0024 - val_mae: 0.0381 - val_mae_denorm: 70.0518
# Epoch 266/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.8602e-05 - mae: 0.0062 - mae_denorm: 1574.2327 - val_loss: 0.0024 - val_mae: 0.0377 - val_mae_denorm: 69.8573
# Epoch 267/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8219e-05 - mae: 0.0040 - mae_denorm: 1556.7766 - val_loss: 0.0028 - val_mae: 0.0429 - val_mae_denorm: 74.3492
# Epoch 268/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1960e-06 - mae: 0.0012 - mae_denorm: 1586.9403 - val_loss: 0.0027 - val_mae: 0.0420 - val_mae_denorm: 73.5111
# Epoch 269/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0794e-06 - mae: 8.1868e-04 - mae_denorm: 1580.1664 - val_loss: 0.0026 - val_mae: 0.0412 - val_mae_denorm: 72.6793
# Epoch 270/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1417e-06 - mae: 0.0010 - mae_denorm: 1565.9672 - val_loss: 0.0023 - val_mae: 0.0372 - val_mae_denorm: 69.2428
# Epoch 271/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.9407e-06 - mae: 0.0017 - mae_denorm: 1560.8068 - val_loss: 0.0026 - val_mae: 0.0416 - val_mae_denorm: 72.9379
# Epoch 272/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0663e-06 - mae: 8.0565e-04 - mae_denorm: 1565.2223 - val_loss: 0.0025 - val_mae: 0.0405 - val_mae_denorm: 71.9061
# Epoch 273/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8213e-07 - mae: 6.5760e-04 - mae_denorm: 1553.6019 - val_loss: 0.0027 - val_mae: 0.0426 - val_mae_denorm: 73.7405
# Epoch 274/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0612e-06 - mae: 0.0014 - mae_denorm: 1568.4744 - val_loss: 0.0025 - val_mae: 0.0405 - val_mae_denorm: 71.8635
# Epoch 275/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3920e-06 - mae: 0.0017 - mae_denorm: 1562.5696 - val_loss: 0.0025 - val_mae: 0.0398 - val_mae_denorm: 71.1702
# Epoch 276/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8213e-06 - mae: 0.0011 - mae_denorm: 1569.2275 - val_loss: 0.0025 - val_mae: 0.0404 - val_mae_denorm: 71.7080
# Epoch 277/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9911e-06 - mae: 0.0020 - mae_denorm: 1580.9056 - val_loss: 0.0020 - val_mae: 0.0337 - val_mae_denorm: 65.9223
# Epoch 278/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7267e-05 - mae: 0.0048 - mae_denorm: 1584.7296 - val_loss: 0.0027 - val_mae: 0.0428 - val_mae_denorm: 74.0565
# Epoch 279/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.3122e-06 - mae: 0.0023 - mae_denorm: 1548.4817 - val_loss: 0.0030 - val_mae: 0.0458 - val_mae_denorm: 76.7779
# Epoch 280/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9168e-05 - mae: 0.0043 - mae_denorm: 1589.1471 - val_loss: 0.0025 - val_mae: 0.0392 - val_mae_denorm: 70.9099
# Epoch 281/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8334e-05 - mae: 0.0070 - mae_denorm: 1592.0038 - val_loss: 0.0024 - val_mae: 0.0379 - val_mae_denorm: 70.3328
# Epoch 282/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7353e-05 - mae: 0.0040 - mae_denorm: 1542.5396 - val_loss: 0.0019 - val_mae: 0.0321 - val_mae_denorm: 63.9941
# Epoch 283/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7445e-04 - mae: 0.0106 - mae_denorm: 1580.1141 - val_loss: 0.0041 - val_mae: 0.0558 - val_mae_denorm: 87.5886
# Epoch 284/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7863e-05 - mae: 0.0044 - mae_denorm: 1557.1924 - val_loss: 0.0039 - val_mae: 0.0536 - val_mae_denorm: 85.3675
# Epoch 285/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2066e-05 - mae: 0.0028 - mae_denorm: 1588.6049 - val_loss: 0.0032 - val_mae: 0.0470 - val_mae_denorm: 78.7168
# Epoch 286/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3559e-06 - mae: 0.0015 - mae_denorm: 1574.0031 - val_loss: 0.0026 - val_mae: 0.0396 - val_mae_denorm: 72.0490
# Epoch 287/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9325e-06 - mae: 0.0013 - mae_denorm: 1598.7363 - val_loss: 0.0027 - val_mae: 0.0415 - val_mae_denorm: 73.5835
# Epoch 288/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1414e-06 - mae: 0.0011 - mae_denorm: 1565.8625 - val_loss: 0.0028 - val_mae: 0.0424 - val_mae_denorm: 74.3981
# Epoch 289/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3412e-05 - mae: 0.0030 - mae_denorm: 1562.9868 - val_loss: 0.0028 - val_mae: 0.0428 - val_mae_denorm: 74.7260
# Epoch 290/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.4142e-06 - mae: 0.0021 - mae_denorm: 1578.2690 - val_loss: 0.0028 - val_mae: 0.0422 - val_mae_denorm: 74.0345
# Epoch 291/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5296e-06 - mae: 0.0012 - mae_denorm: 1593.0245 - val_loss: 0.0030 - val_mae: 0.0453 - val_mae_denorm: 76.7253
# Epoch 292/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.0232e-06 - mae: 0.0017 - mae_denorm: 1580.6249 - val_loss: 0.0026 - val_mae: 0.0403 - val_mae_denorm: 72.3217
# Epoch 293/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7620e-06 - mae: 9.8092e-04 - mae_denorm: 1547.2069 - val_loss: 0.0021 - val_mae: 0.0347 - val_mae_denorm: 67.2001
# Epoch 294/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.8564e-06 - mae: 0.0025 - mae_denorm: 1583.8740 - val_loss: 0.0033 - val_mae: 0.0487 - val_mae_denorm: 79.9460
# Epoch 295/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1651e-05 - mae: 0.0029 - mae_denorm: 1567.5569 - val_loss: 0.0026 - val_mae: 0.0406 - val_mae_denorm: 72.4969
# Epoch 296/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.6169e-06 - mae: 0.0019 - mae_denorm: 1581.6371 - val_loss: 0.0032 - val_mae: 0.0470 - val_mae_denorm: 78.2531
# Epoch 297/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4042e-05 - mae: 0.0029 - mae_denorm: 1538.2090 - val_loss: 0.0023 - val_mae: 0.0371 - val_mae_denorm: 69.4840
# Epoch 298/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2077e-05 - mae: 0.0062 - mae_denorm: 1565.2646 - val_loss: 0.0031 - val_mae: 0.0459 - val_mae_denorm: 77.4574
# Epoch 299/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2381e-05 - mae: 0.0028 - mae_denorm: 1583.8330 - val_loss: 0.0025 - val_mae: 0.0384 - val_mae_denorm: 71.0190
# Epoch 300/300
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.0195e-06 - mae: 0.0018 - mae_denorm: 1572.8527 - val_loss: 0.0027 - val_mae: 0.0408 - val_mae_denorm: 73.0703

# %%
# Plot training & validation loss values
plt.figure(figsize=(15,5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss: mean squared error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Plot training & validation mae values
plt.figure(figsize=(15,5))
plt.plot(hist.history['mae'])
plt.plot(hist.history['val_mae'])
plt.title('Model metric: MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# Plot training & validation mae_denorm values
plt.figure(figsize=(15,5))
plt.plot(hist.history['mae_denorm'])
plt.plot(hist.history['val_mae_denorm'])
plt.title('Model metric: MAE denorm')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train_denorm', 'val_denorm'], loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# # 5. Evaluate the model

# %%
# Load the model from the best epoch (minimum val_loss)
import os
bestmodel_path = max( [ f for f in os.listdir(".") if f.startswith('RNN_ex2_bestmodel_') and f.endswith(".keras") ] )
print( f"The best model: {bestmodel_path}" )

my_rnn_best = keras.models.load_model(bestmodel_path, compile=True)
# Out:
# The best model: RNN_ex2_bestmodel_epoch201.keras

# %%
# Evaluate the model from the last epoch
score = my_rnn.evaluate( x_test_norm, y_test_norm, verbose=0, return_dict=True )
print( "Test results (model from the last epoch):", score )

# Evaluate the model from the best epoch
score = my_rnn_best.evaluate( x_test_norm, y_test_norm, verbose=0, return_dict=True )
print( "Test results (model from the best epoch):", score )
# Out:
# Test results (model from the last epoch): {'loss': 0.06205466762185097, 'mae': 0.23590350151062012, 'mae_denorm': 339.2269287109375}
# Test results (model from the best epoch): {'loss': 0.04646240174770355, 'mae': 0.20215584337711334, 'mae_denorm': 291.68743896484375}

# %% [markdown]
# # 6. Inference

# %%
# Batch prediction
y_pred_norm = my_rnn.predict( x_test_norm )        # Model from the last epoch
y2_pred_norm = my_rnn_best.predict( x_test_norm )  # Model from the best epoch

# Denormalize using training statistics
y_pred = (y_pred_norm * train_std) + train_mean
y2_pred = (y2_pred_norm * train_std) + train_mean

# Show prediction results of the first n data in the test set
n = 20
for i in range( n ):
    print( f"x_test[{i}] = {x_test[i].reshape(1,-1)}" )
    print( f"y_test[{i}] = {y_test[i]}" )
    print( f"y_pred_last_epoch[{i}] = {y_pred[i]} =round=> {np.around( y_pred[i] )}" )
    print( f"y_pred_best_epoch[{i}] = {y2_pred[i]} =round=> {np.around(y2_pred[i])}\n" )
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# x_test[0] = [[1392 1394 1396 1398 1400]]
# y_test[0] = 1402
# y_pred_last_epoch[0] = [1249.20463973] =round=> [1249.]
# y_pred_best_epoch[0] = [1284.31423897] =round=> [1284.]
#
# x_test[1] = [[1394 1396 1398 1400 1402]]
# y_test[1] = 1404
# y_pred_last_epoch[1] = [1250.28360348] =round=> [1250.]
# y_pred_best_epoch[1] = [1285.45531085] =round=> [1285.]
#
# x_test[2] = [[1396 1398 1400 1402 1404]]
# y_test[2] = 1406
# y_pred_last_epoch[2] = [1251.36058505] =round=> [1251.]
# y_pred_best_epoch[2] = [1286.5940702] =round=> [1287.]
#
# x_test[3] = [[1398 1400 1402 1404 1406]]
# y_test[3] = 1408
# y_pred_last_epoch[3] = [1252.43459336] =round=> [1252.]
# y_pred_best_epoch[3] = [1287.73051701] =round=> [1288.]
#
# x_test[4] = [[1400 1402 1404 1406 1408]]
# y_test[4] = 1410
# y_pred_last_epoch[4] = [1253.50628913] =round=> [1254.]
# y_pred_best_epoch[4] = [1288.86399056] =round=> [1289.]
#
# x_test[5] = [[1402 1404 1406 1408 1410]]
# y_test[5] = 1412
# y_pred_last_epoch[5] = [1254.57435092] =round=> [1255.]
# y_pred_best_epoch[5] = [1289.99548194] =round=> [1290.]
#
# x_test[6] = [[1404 1406 1408 1410 1412]]
# y_test[6] = 1414
# y_pred_last_epoch[6] = [1255.64076089] =round=> [1256.]
# y_pred_best_epoch[6] = [1291.12400005] =round=> [1291.]
#
# x_test[7] = [[1406 1408 1410 1412 1414]]
# y_test[7] = 1416
# y_pred_last_epoch[7] = [1256.70386724] =round=> [1257.]
# y_pred_best_epoch[7] = [1292.25020563] =round=> [1292.]
#
# x_test[8] = [[1408 1410 1412 1414 1416]]
# y_test[8] = 1418
# y_pred_last_epoch[8] = [1257.76433069] =round=> [1258.]
# y_pred_best_epoch[8] = [1293.37442903] =round=> [1293.]
#
# x_test[9] = [[1410 1412 1414 1416 1418]]
# y_test[9] = 1420
# y_pred_last_epoch[9] = [1258.82215124] =round=> [1259.]
# y_pred_best_epoch[9] = [1294.49567917] =round=> [1294.]
#
# x_test[10] = [[1412 1414 1416 1418 1420]]
# y_test[10] = 1422
# y_pred_last_epoch[10] = [1259.87732889] =round=> [1260.]
# y_pred_best_epoch[10] = [1295.61428641] =round=> [1296.]
#
# x_test[11] = [[1414 1416 1418 1420 1422]]
# y_test[11] = 1424
# y_pred_last_epoch[11] = [1260.92986364] =round=> [1261.]
# y_pred_best_epoch[11] = [1296.73091147] =round=> [1297.]
#
# x_test[12] = [[1416 1418 1420 1422 1424]]
# y_test[12] = 1426
# y_pred_last_epoch[12] = [1261.97942513] =round=> [1262.]
# y_pred_best_epoch[12] = [1297.84555436] =round=> [1298.]
#
# x_test[13] = [[1418 1420 1422 1424 1426]]
# y_test[13] = 1428
# y_pred_last_epoch[13] = [1263.02634372] =round=> [1263.]
# y_pred_best_epoch[13] = [1298.95689363] =round=> [1299.]
#
# x_test[14] = [[1420 1422 1424 1426 1428]]
# y_test[14] = 1430
# y_pred_last_epoch[14] = [1264.07028904] =round=> [1264.]
# y_pred_best_epoch[14] = [1300.06625072] =round=> [1300.]
#
# x_test[15] = [[1422 1424 1426 1428 1430]]
# y_test[15] = 1432
# y_pred_last_epoch[15] = [1265.11258256] =round=> [1265.]
# y_pred_best_epoch[15] = [1301.17263455] =round=> [1301.]
#
# x_test[16] = [[1424 1426 1428 1430 1432]]
# y_test[16] = 1434
# y_pred_last_epoch[16] = [1266.15157245] =round=> [1266.]
# y_pred_best_epoch[16] = [1302.27736657] =round=> [1302.]
#
# x_test[17] = [[1426 1428 1430 1432 1434]]
# y_test[17] = 1436
# y_pred_last_epoch[17] = [1267.18758908] =round=> [1267.]
# y_pred_best_epoch[17] = [1303.37912532] =round=> [1303.]
#
# x_test[18] = [[1428 1430 1432 1434 1436]]
# y_test[18] = 1438
# y_pred_last_epoch[18] = [1268.22096281] =round=> [1268.]
# y_pred_best_epoch[18] = [1304.47857154] =round=> [1304.]
#
# x_test[19] = [[1430 1432 1434 1436 1438]]
# y_test[19] = 1440
# y_pred_last_epoch[19] = [1269.25169364] =round=> [1269.]
# y_pred_best_epoch[19] = [1305.57537486] =round=> [1306.]
